# %%
# !pip install apache-tvm==0.13.dev248
# Out:
# Requirement already satisfied: apache-tvm==0.13.dev248 in /usr/local/lib/python3.10/dist-packages (0.13.dev248)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from apache-tvm==0.13.dev248) (23.2.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from apache-tvm==0.13.dev248) (2.2.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from apache-tvm==0.13.dev248) (4.4.2)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from apache-tvm==0.13.dev248) (0.2.0)
# Requirement already satisfied: numpy<=1.23 in /usr/local/lib/python3.10/dist-packages (from apache-tvm==0.13.dev248) (1.23.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from apache-tvm==0.13.dev248) (5.9.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from apache-tvm==0.13.dev248) (1.13.0)
# Requirement already satisfied: tornado in /usr/local/lib/python3.10/dist-packages (from apache-tvm==0.13.dev248) (6.3.3)

# %%
import tvm
from tvm import te
from tvm import autotvm
import numpy as np
from tvm.autotvm.tuner import XGBTuner, GATuner, RandomTuner, GridSearchTuner

# %%
#pip install --force-reinstall xgboost==1.5.0

# %%
import xgboost
print(xgboost.__version__)
# Out:
# 1.5.0

# %%
dtype = "float32"
M,N,K = 256, 256, 256
target = "llvm -mcpu=core-avx2"

# %% [markdown]
# **Run AutoTVM tuning**

# %%
def run_tuning(tasks, measure_option, tuner="gridsearch", early_stopping=None,
               log_filename="tuning.log", n_trial=None):
    for i, task in enumerate(tasks):
        prefix = "[Task %2d/%2d] " % (i + 1, len(tasks))

        # create tuner
        if tuner == "xgb" or tuner == "xgb-rank":
            tuner_obj = XGBTuner(task, loss_type="rank")
        elif tuner == "ga":
            tuner_obj = GATuner(task, pop_size=50)
        elif tuner == "random":
            tuner_obj = RandomTuner(task)
        elif tuner == "gridsearch":
            tuner_obj = GridSearchTuner(task)
        else:
            raise ValueError("Invalid tuner: " + tuner)

        # do tuning
        n_trial = min(n_trial or len(task.config_space), len(task.config_space))
        tuner_obj.tune(
            n_trial=n_trial or len(task.config_space),
            early_stopping=early_stopping,
            measure_option=measure_option,
            callbacks=[
                autotvm.callback.progress_bar(n_trial, prefix=prefix),
                autotvm.callback.log_to_file(log_filename),
            ],
        )

# %%
def get_tuning_option(log_file="tune.log"): return {
    "log_filename": log_file,
    "n_trial": 300,
    "tuner": "xgb",
    "early_stopping": None,
    "measure_option": autotvm.measure_option(
        builder=autotvm.LocalBuilder(),
        runner=autotvm.LocalRunner(
            number=1, repeat=10, min_repeat_ms=0, enable_cpu_cache_flush=True
        ),
    ),
}

# %%
@autotvm.template("matmul_template_wo_filter")
def matmul_template_wo_filter(N, M, K):
    k = te.reduce_axis((0, K), "k")
    A = te.placeholder((M, K), name="A", dtype=dtype)
    B = te.placeholder((K, N), name="B", dtype=dtype)
    C = te.compute((M, N), lambda m, n: te.sum(A[m, k] * B[k, n], axis=k), name="C")
    s = te.create_schedule(C.op)
    # schedule
    y, x = s[C].op.axis
    k = s[C].op.reduce_axis[0]
    ##### define space #####
    cfg = autotvm.get_config()
    cfg.define_split("tile_y", y, num_outputs=2)
    cfg.define_split("tile_x", x, num_outputs=2)
    # schedule according to config
    yo, yi = cfg["tile_y"].apply(s, C, y)
    xo, xi = cfg["tile_x"].apply(s, C, x)
    s[C].reorder(yo, xo, k, yi, xi)
    return s, [A, B, C]

task1 = autotvm.task.create("matmul_template_wo_filter", args=(M, N, K), target=target)
print(task1.config_space)
for idx in range(task1.config_space.range_length):
    if task1.config_space.is_index_valid(idx):
        print(task1.config_space.get(idx))
# Out:
# ConfigSpace (len=81, range_length=81, space_map=
#    0 tile_y: Split(policy=factors, product=256, num_outputs=2) len=9
#    1 tile_x: Split(policy=factors, product=256, num_outputs=2) len=9
# )
# [('tile_y', [-1, 1]), ('tile_x', [-1, 1])],None,0
# [('tile_y', [-1, 2]), ('tile_x', [-1, 1])],None,1
# [('tile_y', [-1, 4]), ('tile_x', [-1, 1])],None,2
# [('tile_y', [-1, 8]), ('tile_x', [-1, 1])],None,3
# [('tile_y', [-1, 16]), ('tile_x', [-1, 1])],None,4
# [('tile_y', [-1, 32]), ('tile_x', [-1, 1])],None,5
# [('tile_y', [-1, 64]), ('tile_x', [-1, 1])],None,6
# [('tile_y', [-1, 128]), ('tile_x', [-1, 1])],None,7
# [('tile_y', [-1, 256]), ('tile_x', [-1, 1])],None,8
# [('tile_y', [-1, 1]), ('tile_x', [-1, 2])],None,9
# [('tile_y', [-1, 2]), ('tile_x', [-1, 2])],None,10
# [('tile_y', [-1, 4]), ('tile_x', [-1, 2])],None,11
# [('tile_y', [-1, 8]), ('tile_x', [-1, 2])],None,12
# [('tile_y', [-1, 16]), ('tile_x', [-1, 2])],None,13
# [('tile_y', [-1, 32]), ('tile_x', [-1, 2])],None,14
# [('tile_y', [-1, 64]), ('tile_x', [-1, 2])],None,15
# [('tile_y', [-1, 128]), ('tile_x', [-1, 2])],None,16
# [('tile_y', [-1, 256]), ('tile_x', [-1, 2])],None,17
# [('tile_y', [-1, 1]), ('tile_x', [-1, 4])],None,18
# [('tile_y', [-1, 2]), ('tile_x', [-1, 4])],None,19
# [('tile_y', [-1, 4]), ('tile_x', [-1, 4])],None,20
# [('tile_y', [-1, 8]), ('tile_x', [-1, 4])],None,21
# [('tile_y', [-1, 16]), ('tile_x', [-1, 4])],None,22
# [('tile_y', [-1, 32]), ('tile_x', [-1, 4])],None,23
# [('tile_y', [-1, 64]), ('tile_x', [-1, 4])],None,24
# [('tile_y', [-1, 128]), ('tile_x', [-1, 4])],None,25
# [('tile_y', [-1, 256]), ('tile_x', [-1, 4])],None,26
# [('tile_y', [-1, 1]), ('tile_x', [-1, 8])],None,27
# [('tile_y', [-1, 2]), ('tile_x', [-1, 8])],None,28
# [('tile_y', [-1, 4]), ('tile_x', [-1, 8])],None,29
# [('tile_y', [-1, 8]), ('tile_x', [-1, 8])],None,30
# [('tile_y', [-1, 16]), ('tile_x', [-1, 8])],None,31
# [('tile_y', [-1, 32]), ('tile_x', [-1, 8])],None,32
# [('tile_y', [-1, 64]), ('tile_x', [-1, 8])],None,33
# [('tile_y', [-1, 128]), ('tile_x', [-1, 8])],None,34
# [('tile_y', [-1, 256]), ('tile_x', [-1, 8])],None,35
# [('tile_y', [-1, 1]), ('tile_x', [-1, 16])],None,36
# [('tile_y', [-1, 2]), ('tile_x', [-1, 16])],None,37
# [('tile_y', [-1, 4]), ('tile_x', [-1, 16])],None,38
# [('tile_y', [-1, 8]), ('tile_x', [-1, 16])],None,39
# [('tile_y', [-1, 16]), ('tile_x', [-1, 16])],None,40
# [('tile_y', [-1, 32]), ('tile_x', [-1, 16])],None,41
# [('tile_y', [-1, 64]), ('tile_x', [-1, 16])],None,42
# [('tile_y', [-1, 128]), ('tile_x', [-1, 16])],None,43
# [('tile_y', [-1, 256]), ('tile_x', [-1, 16])],None,44
# [('tile_y', [-1, 1]), ('tile_x', [-1, 32])],None,45
# [('tile_y', [-1, 2]), ('tile_x', [-1, 32])],None,46
# [('tile_y', [-1, 4]), ('tile_x', [-1, 32])],None,47
# [('tile_y', [-1, 8]), ('tile_x', [-1, 32])],None,48
# [('tile_y', [-1, 16]), ('tile_x', [-1, 32])],None,49
# [('tile_y', [-1, 32]), ('tile_x', [-1, 32])],None,50
# [('tile_y', [-1, 64]), ('tile_x', [-1, 32])],None,51
# [('tile_y', [-1, 128]), ('tile_x', [-1, 32])],None,52
# [('tile_y', [-1, 256]), ('tile_x', [-1, 32])],None,53
# [('tile_y', [-1, 1]), ('tile_x', [-1, 64])],None,54
# [('tile_y', [-1, 2]), ('tile_x', [-1, 64])],None,55
# [('tile_y', [-1, 4]), ('tile_x', [-1, 64])],None,56
# [('tile_y', [-1, 8]), ('tile_x', [-1, 64])],None,57
# [('tile_y', [-1, 16]), ('tile_x', [-1, 64])],None,58
# [('tile_y', [-1, 32]), ('tile_x', [-1, 64])],None,59
# [('tile_y', [-1, 64]), ('tile_x', [-1, 64])],None,60
# [('tile_y', [-1, 128]), ('tile_x', [-1, 64])],None,61
# [('tile_y', [-1, 256]), ('tile_x', [-1, 64])],None,62
# [('tile_y', [-1, 1]), ('tile_x', [-1, 128])],None,63
# [('tile_y', [-1, 2]), ('tile_x', [-1, 128])],None,64
# [('tile_y', [-1, 4]), ('tile_x', [-1, 128])],None,65
# [('tile_y', [-1, 8]), ('tile_x', [-1, 128])],None,66
# [('tile_y', [-1, 16]), ('tile_x', [-1, 128])],None,67
# [('tile_y', [-1, 32]), ('tile_x', [-1, 128])],None,68
# [('tile_y', [-1, 64]), ('tile_x', [-1, 128])],None,69
# [('tile_y', [-1, 128]), ('tile_x', [-1, 128])],None,70
# [('tile_y', [-1, 256]), ('tile_x', [-1, 128])],None,71
# [('tile_y', [-1, 1]), ('tile_x', [-1, 256])],None,72
# [('tile_y', [-1, 2]), ('tile_x', [-1, 256])],None,73
# [('tile_y', [-1, 4]), ('tile_x', [-1, 256])],None,74
# [('tile_y', [-1, 8]), ('tile_x', [-1, 256])],None,75
# [('tile_y', [-1, 16]), ('tile_x', [-1, 256])],None,76
# [('tile_y', [-1, 32]), ('tile_x', [-1, 256])],None,77
# [('tile_y', [-1, 64]), ('tile_x', [-1, 256])],None,78
# [('tile_y', [-1, 128]), ('tile_x', [-1, 256])],None,79
# [('tile_y', [-1, 256]), ('tile_x', [-1, 256])],None,80

# %%
@autotvm.template("matmul_template_with_filter")
def matmul_template_with_filter(N, M, K):
    k = te.reduce_axis((0, K), "k")
    A = te.placeholder((M, K), name="A", dtype=dtype)
    B = te.placeholder((K, N), name="B", dtype=dtype)
    C = te.compute((M, N), lambda m, n: te.sum(A[m, k] * B[k, n], axis=k), name="C")
    s = te.create_schedule(C.op)
    # schedule
    y, x = s[C].op.axis
    k = s[C].op.reduce_axis[0]
    ##### define space #####
    cfg = autotvm.get_config()
    cfg.define_split("tile_y", y, num_outputs=2)
    cfg.define_split("tile_x", x, num_outputs=2, filter= lambda v: v.size[1] >= 32)
    # schedule according to config
    yo, yi = cfg["tile_y"].apply(s, C, y)
    xo, xi = cfg["tile_x"].apply(s, C, x)
    s[C].reorder(yo, xo, k, yi, xi)
    return s, [A, B, C]


task2 = autotvm.task.create("matmul_template_with_filter", args=(M, N, K), target=target)
print(task2.config_space)
for idx in range(task2.config_space.range_length):
    if task2.config_space.is_index_valid(idx):
        print(task2.config_space.get(idx))
# Out:
# ConfigSpace (len=36, range_length=36, space_map=
#    0 tile_y: Split(policy=factors, product=256, num_outputs=2) len=9
#    1 tile_x: Split(policy=factors, product=256, num_outputs=2) len=4
# )
# [('tile_y', [-1, 1]), ('tile_x', [-1, 32])],None,0
# [('tile_y', [-1, 2]), ('tile_x', [-1, 32])],None,1
# [('tile_y', [-1, 4]), ('tile_x', [-1, 32])],None,2
# [('tile_y', [-1, 8]), ('tile_x', [-1, 32])],None,3
# [('tile_y', [-1, 16]), ('tile_x', [-1, 32])],None,4
# [('tile_y', [-1, 32]), ('tile_x', [-1, 32])],None,5
# [('tile_y', [-1, 64]), ('tile_x', [-1, 32])],None,6
# [('tile_y', [-1, 128]), ('tile_x', [-1, 32])],None,7
# [('tile_y', [-1, 256]), ('tile_x', [-1, 32])],None,8
# [('tile_y', [-1, 1]), ('tile_x', [-1, 64])],None,9
# [('tile_y', [-1, 2]), ('tile_x', [-1, 64])],None,10
# [('tile_y', [-1, 4]), ('tile_x', [-1, 64])],None,11
# [('tile_y', [-1, 8]), ('tile_x', [-1, 64])],None,12
# [('tile_y', [-1, 16]), ('tile_x', [-1, 64])],None,13
# [('tile_y', [-1, 32]), ('tile_x', [-1, 64])],None,14
# [('tile_y', [-1, 64]), ('tile_x', [-1, 64])],None,15
# [('tile_y', [-1, 128]), ('tile_x', [-1, 64])],None,16
# [('tile_y', [-1, 256]), ('tile_x', [-1, 64])],None,17
# [('tile_y', [-1, 1]), ('tile_x', [-1, 128])],None,18
# [('tile_y', [-1, 2]), ('tile_x', [-1, 128])],None,19
# [('tile_y', [-1, 4]), ('tile_x', [-1, 128])],None,20
# [('tile_y', [-1, 8]), ('tile_x', [-1, 128])],None,21
# [('tile_y', [-1, 16]), ('tile_x', [-1, 128])],None,22
# [('tile_y', [-1, 32]), ('tile_x', [-1, 128])],None,23
# [('tile_y', [-1, 64]), ('tile_x', [-1, 128])],None,24
# [('tile_y', [-1, 128]), ('tile_x', [-1, 128])],None,25
# [('tile_y', [-1, 256]), ('tile_x', [-1, 128])],None,26
# [('tile_y', [-1, 1]), ('tile_x', [-1, 256])],None,27
# [('tile_y', [-1, 2]), ('tile_x', [-1, 256])],None,28
# [('tile_y', [-1, 4]), ('tile_x', [-1, 256])],None,29
# [('tile_y', [-1, 8]), ('tile_x', [-1, 256])],None,30
# [('tile_y', [-1, 16]), ('tile_x', [-1, 256])],None,31
# [('tile_y', [-1, 32]), ('tile_x', [-1, 256])],None,32
# [('tile_y', [-1, 64]), ('tile_x', [-1, 256])],None,33
# [('tile_y', [-1, 128]), ('tile_x', [-1, 256])],None,34
# [('tile_y', [-1, 256]), ('tile_x', [-1, 256])],None,35

# %%
@autotvm.template("matmul_template_with_multi_filter")
def matmul_template_with_multi_filter(N, M, K):
    k = te.reduce_axis((0, K), "k")
    A = te.placeholder((M, K), name="A", dtype=dtype)
    B = te.placeholder((K, N), name="B", dtype=dtype)
    C = te.compute((M, N), lambda m, n: te.sum(A[m, k] * B[k, n], axis=k), name="C")
    s = te.create_schedule(C.op)
    # schedule
    y, x = s[C].op.axis
    k = s[C].op.reduce_axis[0]
    ##### define space #####
    cfg = autotvm.get_config()
    cfg.define_split("tile_y", y, num_outputs=2)
    cfg.define_split("tile_x", x, num_outputs=2, filter= lambda v: v.size[1] >= 32)
    cfg.multi_filter(filter=lambda e: e["tile_x"].size[1] > e["tile_y"].size[1])
    # schedule according to config
    yo, yi = cfg["tile_y"].apply(s, C, y)
    xo, xi = cfg["tile_x"].apply(s, C, x)
    s[C].reorder(yo, xo, k, yi, xi)
    return s, [A, B, C]

task3 = autotvm.task.create("matmul_template_with_multi_filter", args=(M, N, K), target=target)
print(task3.config_space)
for idx in range(task3.config_space.range_length):
    if task3.config_space.is_index_valid(idx):
        print(task3.config_space.get(idx))
# Out:
# ConfigSpace (len=26, range_length=36, space_map=
#    0 tile_y: Split(policy=factors, product=256, num_outputs=2) len=9
#    1 tile_x: Split(policy=factors, product=256, num_outputs=2) len=4
# )
# [('tile_y', [-1, 1]), ('tile_x', [-1, 32])],None,0
# [('tile_y', [-1, 2]), ('tile_x', [-1, 32])],None,1
# [('tile_y', [-1, 4]), ('tile_x', [-1, 32])],None,2
# [('tile_y', [-1, 8]), ('tile_x', [-1, 32])],None,3
# [('tile_y', [-1, 16]), ('tile_x', [-1, 32])],None,4
# [('tile_y', [-1, 1]), ('tile_x', [-1, 64])],None,9
# [('tile_y', [-1, 2]), ('tile_x', [-1, 64])],None,10
# [('tile_y', [-1, 4]), ('tile_x', [-1, 64])],None,11
# [('tile_y', [-1, 8]), ('tile_x', [-1, 64])],None,12
# [('tile_y', [-1, 16]), ('tile_x', [-1, 64])],None,13
# [('tile_y', [-1, 32]), ('tile_x', [-1, 64])],None,14
# [('tile_y', [-1, 1]), ('tile_x', [-1, 128])],None,18
# [('tile_y', [-1, 2]), ('tile_x', [-1, 128])],None,19
# [('tile_y', [-1, 4]), ('tile_x', [-1, 128])],None,20
# [('tile_y', [-1, 8]), ('tile_x', [-1, 128])],None,21
# [('tile_y', [-1, 16]), ('tile_x', [-1, 128])],None,22
# [('tile_y', [-1, 32]), ('tile_x', [-1, 128])],None,23
# [('tile_y', [-1, 64]), ('tile_x', [-1, 128])],None,24
# [('tile_y', [-1, 1]), ('tile_x', [-1, 256])],None,27
# [('tile_y', [-1, 2]), ('tile_x', [-1, 256])],None,28
# [('tile_y', [-1, 4]), ('tile_x', [-1, 256])],None,29
# [('tile_y', [-1, 8]), ('tile_x', [-1, 256])],None,30
# [('tile_y', [-1, 16]), ('tile_x', [-1, 256])],None,31
# [('tile_y', [-1, 32]), ('tile_x', [-1, 256])],None,32
# [('tile_y', [-1, 64]), ('tile_x', [-1, 256])],None,33
# [('tile_y', [-1, 128]), ('tile_x', [-1, 256])],None,34

# %%
tasks = [task1]
run_tuning(tasks, **get_tuning_option("log_file_1.log"))
# Out:
# [Task  1/ 1]  Current/Best:    3.81/  29.74 GFLOPS | Progress: (81/81) | 73.57 s Done.

# %%
dispatch_context = autotvm.apply_history_best("log_file_1.log")
best_config = dispatch_context.query(task1.target, task1.workload)

print("\nBest config:")
print(best_config)
with dispatch_context:
    with tvm.target.Target(target):
      s, (A, B, C) = matmul_template_wo_filter(M, N, K)
      func = tvm.build(s, [A, B, C], target=target, name="matmul")
      lowered_func = tvm.lower(s, [A, B, C])
      print(lowered_func)
# Out:
# Best config:
# [('tile_y', [-1, 1]), ('tile_x', [-1, 64])],None,54
# # from tvm.script import ir as I
# # from tvm.script import tir as T
#
# @I.ir_module
# class Module:
#     @T.prim_func
#     def main(A: T.Buffer((256, 256), "float32"), B: T.Buffer((256, 256), "float32"), C: T.Buffer((256, 256), "float32")):
#         T.func_attr({"from_legacy_te_schedule": T.bool(True), "global_symbol": "main", "tir.noalias": T.bool(True)})
#         for m_outer, n_outer in T.grid(256, 4):
#             C_1 = T.Buffer((65536,), data=C.data)
#             for n_inner_init in range(64):
#                 C_1[m_outer * 256 + n_outer * 64 + n_inner_init] = T.float32(0)
#             for k, n_inner in T.grid(256, 64):
#                 cse_var_3: T.int32 = m_outer * 256
#                 cse_var_2: T.int32 = n_outer * 64
#                 cse_var_1: T.int32 = cse_var_3 + cse_var_2 + n_inner
#                 A_1 = T.Buffer((65536,), data=A.data)
#                 B_1 = T.Buffer((65536,), data=B.data)
#                 C_1[cse_var_1] = C_1[cse_var_1] + A_1[cse_var_3 + k] * B_1[k * 256 + cse_var_2 + n_inner]

# %%
tasks = [task2]
run_tuning(tasks, **get_tuning_option("log_file_2.log"))
# Out:
# [Task  1/ 1]  Current/Best:   18.12/  29.81 GFLOPS | Progress: (36/36) | 30.59 s Done.

# %%
dispatch_context = autotvm.apply_history_best("log_file_2.log")
best_config = dispatch_context.query(task2.target, task2.workload)
print("\nBest config:")
print(best_config)
with dispatch_context:
    with tvm.target.Target(target):
        s, (A, B, C) = matmul_template_with_filter(M, N, K)
        func = tvm.build(s, [A, B, C], target=target, name="matmul")
        lowered_func = tvm.lower(s, [A, B, C])
        print(lowered_func)
# Out:
# Best config:
# [('tile_y', [-1, 1]), ('tile_x', [-1, 64])],None,9
# # from tvm.script import ir as I
# # from tvm.script import tir as T
#
# @I.ir_module
# class Module:
#     @T.prim_func
#     def main(A: T.Buffer((256, 256), "float32"), B: T.Buffer((256, 256), "float32"), C: T.Buffer((256, 256), "float32")):
#         T.func_attr({"from_legacy_te_schedule": T.bool(True), "global_symbol": "main", "tir.noalias": T.bool(True)})
#         for m_outer, n_outer in T.grid(256, 4):
#             C_1 = T.Buffer((65536,), data=C.data)
#             for n_inner_init in range(64):
#                 C_1[m_outer * 256 + n_outer * 64 + n_inner_init] = T.float32(0)
#             for k, n_inner in T.grid(256, 64):
#                 cse_var_3: T.int32 = m_outer * 256
#                 cse_var_2: T.int32 = n_outer * 64
#                 cse_var_1: T.int32 = cse_var_3 + cse_var_2 + n_inner
#                 A_1 = T.Buffer((65536,), data=A.data)
#                 B_1 = T.Buffer((65536,), data=B.data)
#                 C_1[cse_var_1] = C_1[cse_var_1] + A_1[cse_var_3 + k] * B_1[k * 256 + cse_var_2 + n_inner]

# %%
tasks = [task3]
run_tuning(tasks, **get_tuning_option("log_file_3.log"))
# Out:
# [Task  1/ 1]  Current/Best:   22.32/  29.72 GFLOPS | Progress: (26/26) | 28.49 s Done.

# %%
dispatch_context = autotvm.apply_history_best("log_file_3.log")
best_config = dispatch_context.query(task3.target, task3.workload)
print("\nBest config:")
print(best_config)
with dispatch_context:
    with tvm.target.Target(target):
        s, (A, B, C) = matmul_template_with_multi_filter(M, N, K)
        func = tvm.build(s, [A, B, C], target=target, name="matmul")
        lowered_func = tvm.lower(s, [A, B, C])
        print(lowered_func)
# Out:
# Best config:
# [('tile_y', [-1, 1]), ('tile_x', [-1, 32])],None,0
# # from tvm.script import ir as I
# # from tvm.script import tir as T
#
# @I.ir_module
# class Module:
#     @T.prim_func
#     def main(A: T.Buffer((256, 256), "float32"), B: T.Buffer((256, 256), "float32"), C: T.Buffer((256, 256), "float32")):
#         T.func_attr({"from_legacy_te_schedule": T.bool(True), "global_symbol": "main", "tir.noalias": T.bool(True)})
#         for m_outer, n_outer in T.grid(256, 8):
#             C_1 = T.Buffer((65536,), data=C.data)
#             for n_inner_init in range(32):
#                 C_1[m_outer * 256 + n_outer * 32 + n_inner_init] = T.float32(0)
#             for k, n_inner in T.grid(256, 32):
#                 cse_var_3: T.int32 = m_outer * 256
#                 cse_var_2: T.int32 = n_outer * 32
#                 cse_var_1: T.int32 = cse_var_3 + cse_var_2 + n_inner
#                 A_1 = T.Buffer((65536,), data=A.data)
#                 B_1 = T.Buffer((65536,), data=B.data)
#                 C_1[cse_var_1] = C_1[cse_var_1] + A_1[cse_var_3 + k] * B_1[k * 256 + cse_var_2 + n_inner]

# %%
dev = tvm.cpu(0)
a = np.random.uniform(size=(M, K)).astype("float32")
b = np.random.uniform(size=(K, N)).astype("float32")
c_tvm = tvm.nd.array(np.zeros((M, N), dtype="float32"), dev)
c_np = np.matmul(a, b)
a = tvm.nd.array(a)
b = tvm.nd.array(b)

# %%
time_f = func.time_evaluator(func.entry_name, dev, number=10)
cost = time_f(a,b,c_tvm).mean
print("func", cost*1000)
# Out:
# func 1.6896211

# %%
print(func.get_source())
# Out:
# ; ModuleID = 'TVMMod'
# source_filename = "TVMMod"
# target datalayout = "e-m:e-p270:32:32-p271:32:32-p272:64:64-i64:64-f80:128-n8:16:32:64-S128"
# target triple = "x86_64-unknown-linux-gnu"
#
# %0 = type { i8*, %1, i32, %2, i64*, i64*, i64 }
# %1 = type { i32, i32 }
# %2 = type { i8, i8, i16 }
#
# @__TVMAPISetLastError = linkonce dllexport local_unnamed_addr global void (i8*)* null, align 8
# @.str = private constant [57 x i8] c"Assert fail: num_args == 3, matmul: num_args should be 3\00", align 1
# @.str.1 = private constant [108 x i8] c"Assert fail: A_code == 3 or A_code == 13 or A_code == 7 or A_code == 4, matmul: Expect arg[0] to be pointer\00", align 1
# @.str.2 = private constant [108 x i8] c"Assert fail: B_code == 3 or B_code == 13 or B_code == 7 or B_code == 4, matmul: Expect arg[1] to be pointer\00", align 1
# @.str.3 = private constant [108 x i8] c"Assert fail: C_code == 3 or C_code == 13 or C_code == 7 or C_code == 4, matmul: Expect arg[2] to be pointer\00", align 1
# @.str.4 = private constant [91 x i8] c"Assert fail: 2 == T.tvm_struct_get(A, 0, 4, \22int32\22), matmul.A.ndim is expected to equal 2\00", align 1
# @.str.5 = private constant [213 x i8] c"Assert fail: T.tvm_struct_get(A, 0, 5, \22uint8\22) == T.uint8(2) and T.tvm_struct_get(A, 0, 6, \22uint8\22) == T.uint8(32) and T.tvm_struct_get(A, 0, 7, \22uint16\22) == T.uint16(1), matmul.A.dtype is expected to be float32\00", align 1
# @.str.6 = private constant [156 x i8] c"Assert fail: T.Cast(\22int32\22, matmul_A_shape[0]) == 256, Argument matmul.A.shape[0] has an unsatisfied constraint: 256 == T.Cast(\22int32\22, matmul_A_shape[0])\00", align 1
# @.str.7 = private constant [156 x i8] c"Assert fail: T.Cast(\22int32\22, matmul_A_shape[1]) == 256, Argument matmul.A.shape[1] has an unsatisfied constraint: 256 == T.Cast(\22int32\22, matmul_A_shape[1])\00", align 1
# @.str.8 = private constant [151 x i8] c"Assert fail: 1 == T.Cast(\22int32\22, matmul_A_strides[1]) and 256 == T.Cast(\22int32\22, matmul_A_strides[0]), matmul.A.strides: expected to be compact array\00", align 1
# @.str.9 = private constant [177 x i8] c"Assert fail: T.uint64(0) == T.tvm_struct_get(A, 0, 8, \22uint64\22), Argument matmul.A.byte_offset has an unsatisfied constraint: T.uint64(0) == T.tvm_struct_get(A, 0, 8, \22uint64\22)\00", align 1
# @.str.10 = private constant [157 x i8] c"Assert fail: T.tvm_struct_get(A, 0, 10, \22int32\22) == 1, Argument matmul.A.device_type has an unsatisfied constraint: 1 == T.tvm_struct_get(A, 0, 10, \22int32\22)\00", align 1
# @.str.11 = private constant [91 x i8] c"Assert fail: 2 == T.tvm_struct_get(B, 0, 4, \22int32\22), matmul.B.ndim is expected to equal 2\00", align 1
# @.str.12 = private constant [213 x i8] c"Assert fail: T.tvm_struct_get(B, 0, 5, \22uint8\22) == T.uint8(2) and T.tvm_struct_get(B, 0, 6, \22uint8\22) == T.uint8(32) and T.tvm_struct_get(B, 0, 7, \22uint16\22) == T.uint16(1), matmul.B.dtype is expected to be float32\00", align 1
# @.str.13 = private constant [156 x i8] c"Assert fail: T.Cast(\22int32\22, matmul_B_shape[0]) == 256, Argument matmul.B.shape[0] has an unsatisfied constraint: 256 == T.Cast(\22int32\22, matmul_B_shape[0])\00", align 1
# @.str.14 = private constant [156 x i8] c"Assert fail: T.Cast(\22int32\22, matmul_B_shape[1]) == 256, Argument matmul.B.shape[1] has an unsatisfied constraint: 256 == T.Cast(\22int32\22, matmul_B_shape[1])\00", align 1
# @.str.15 = private constant [151 x i8] c"Assert fail: 1 == T.Cast(\22int32\22, matmul_B_strides[1]) and 256 == T.Cast(\22int32\22, matmul_B_strides[0]), matmul.B.strides: expected to be compact array\00", align 1
# @.str.16 = private constant [177 x i8] c"Assert fail: T.uint64(0) == T.tvm_struct_get(B, 0, 8, \22uint64\22), Argument matmul.B.byte_offset has an unsatisfied constraint: T.uint64(0) == T.tvm_struct_get(B, 0, 8, \22uint64\22)\00", align 1
# @.str.17 = private constant [157 x i8] c"Assert fail: T.tvm_struct_get(B, 0, 10, \22int32\22) == 1, Argument matmul.B.device_type has an unsatisfied constraint: 1 == T.tvm_struct_get(B, 0, 10, \22int32\22)\00", align 1
# @.str.18 = private constant [163 x i8] c"Assert fail: dev_id == T.tvm_struct_get(B, 0, 9, \22int32\22), Argument matmul.B.device_id has an unsatisfied constraint: dev_id == T.tvm_struct_get(B, 0, 9, \22int32\22)\00", align 1
# @.str.19 = private constant [91 x i8] c"Assert fail: 2 == T.tvm_struct_get(C, 0, 4, \22int32\22), matmul.C.ndim is expected to equal 2\00", align 1
# @.str.20 = private constant [213 x i8] c"Assert fail: T.tvm_struct_get(C, 0, 5, \22uint8\22) == T.uint8(2) and T.tvm_struct_get(C, 0, 6, \22uint8\22) == T.uint8(32) and T.tvm_struct_get(C, 0, 7, \22uint16\22) == T.uint16(1), matmul.C.dtype is expected to be float32\00", align 1
# @.str.21 = private constant [156 x i8] c"Assert fail: T.Cast(\22int32\22, matmul_C_shape[0]) == 256, Argument matmul.C.shape[0] has an unsatisfied constraint: 256 == T.Cast(\22int32\22, matmul_C_shape[0])\00", align 1
# @.str.22 = private constant [156 x i8] c"Assert fail: T.Cast(\22int32\22, matmul_C_shape[1]) == 256, Argument matmul.C.shape[1] has an unsatisfied constraint: 256 == T.Cast(\22int32\22, matmul_C_shape[1])\00", align 1
# @.str.23 = private constant [151 x i8] c"Assert fail: 1 == T.Cast(\22int32\22, matmul_C_strides[1]) and 256 == T.Cast(\22int32\22, matmul_C_strides[0]), matmul.C.strides: expected to be compact array\00", align 1
# @.str.24 = private constant [177 x i8] c"Assert fail: T.uint64(0) == T.tvm_struct_get(C, 0, 8, \22uint64\22), Argument matmul.C.byte_offset has an unsatisfied constraint: T.uint64(0) == T.tvm_struct_get(C, 0, 8, \22uint64\22)\00", align 1
# @.str.25 = private constant [157 x i8] c"Assert fail: T.tvm_struct_get(C, 0, 10, \22int32\22) == 1, Argument matmul.C.device_type has an unsatisfied constraint: 1 == T.tvm_struct_get(C, 0, 10, \22int32\22)\00", align 1
# @.str.26 = private constant [163 x i8] c"Assert fail: dev_id == T.tvm_struct_get(C, 0, 9, \22int32\22), Argument matmul.C.device_id has an unsatisfied constraint: dev_id == T.tvm_struct_get(C, 0, 9, \22int32\22)\00", align 1
# @__tvm_main__ = weak dllexport local_unnamed_addr constant [7 x i8] c"matmul\00", align 1
# @llvm.global_ctors = appending global [0 x { i32, void ()*, i8* }] zeroinitializer
#
# define dllexport i32 @matmul(i8* noalias nocapture readonly %args, i32* noalias nocapture readonly %arg_type_ids, i32 %num_args, i8* noalias nocapture readnone %out_ret_value, i32* noalias nocapture readnone %out_ret_tcode, i8* noalias nocapture readnone %resource_handle) local_unnamed_addr #0 !dbg !5 {
# entry:
#   call void @llvm.dbg.value(metadata i8* %args, metadata !12, metadata !DIExpression()), !dbg !18
#   call void @llvm.dbg.value(metadata i32* %arg_type_ids, metadata !13, metadata !DIExpression()), !dbg !18
#   call void @llvm.dbg.value(metadata i32 %num_args, metadata !14, metadata !DIExpression()), !dbg !18
#   call void @llvm.dbg.value(metadata i8* %out_ret_value, metadata !15, metadata !DIExpression()), !dbg !18
#   call void @llvm.dbg.value(metadata i32* %out_ret_tcode, metadata !16, metadata !DIExpression()), !dbg !18
#   call void @llvm.dbg.value(metadata i8* %resource_handle, metadata !17, metadata !DIExpression()), !dbg !18
#   %0 = icmp eq i32 %num_args, 3, !dbg !18
#   br i1 %0, label %assert_end, label %assert_fail, !dbg !18, !prof !19
#
# assert_fail:                                      ; preds = %entry
#   %1 = load void (i8*)*, void (i8*)** @__TVMAPISetLastError, align 8, !dbg !18, !tbaa !20
#   tail call void %1(i8* getelementptr inbounds ([57 x i8], [57 x i8]* @.str, i64 0, i64 0)), !dbg !18
#   ret i32 -1, !dbg !18
#
# assert_end:                                       ; preds = %entry
#   %A.code = load i32, i32* %arg_type_ids, align 4, !dbg !18, !tbaa !23
#   %2 = getelementptr inbounds i32, i32* %arg_type_ids, i64 1, !dbg !18
#   %B.code = load i32, i32* %2, align 4, !dbg !18, !tbaa !34
#   %3 = getelementptr inbounds i32, i32* %arg_type_ids, i64 2, !dbg !18
#   %C.code = load i32, i32* %3, align 4, !dbg !18, !tbaa !36
#   %4 = bitcast i8* %args to %0**, !dbg !18
#   %A75 = load %0*, %0** %4, align 8, !dbg !18
#   %5 = getelementptr inbounds i8, i8* %args, i64 8, !dbg !18
#   %6 = bitcast i8* %5 to %0**, !dbg !18
#   %B76 = load %0*, %0** %6, align 8, !dbg !18
#   %7 = getelementptr inbounds i8, i8* %args, i64 16, !dbg !18
#   %8 = bitcast i8* %7 to %0**, !dbg !18
#   %C77 = load %0*, %0** %8, align 8, !dbg !18
#   %9 = bitcast %0* %A75 to float**, !dbg !18
#   %A_void_ptr78 = load float*, float** %9, align 8, !dbg !18
#   %ptrint = ptrtoint float* %A_void_ptr78 to i64, !dbg !18
#   %maskedptr = and i64 %ptrint, 63, !dbg !18
#   %maskcond = icmp eq i64 %maskedptr, 0, !dbg !18
#   tail call void @llvm.assume(i1 %maskcond), !dbg !18
#   %10 = getelementptr inbounds %0, %0* %A75, i64 0, i32 4, !dbg !18
#   %matmul.A.shape = load i64*, i64** %10, align 8, !dbg !18
#   %11 = getelementptr inbounds %0, %0* %A75, i64 0, i32 5, !dbg !18
#   %matmul.A.strides = load i64*, i64** %11, align 8, !dbg !18
#   %12 = getelementptr inbounds %0, %0* %A75, i64 0, i32 1, i32 1, !dbg !18
#   %dev_id = load i32, i32* %12, align 4, !dbg !18
#   %13 = bitcast %0* %B76 to float**, !dbg !18
#   %B_void_ptr79 = load float*, float** %13, align 8, !dbg !18
#   %ptrint3 = ptrtoint float* %B_void_ptr79 to i64, !dbg !18
#   %maskedptr4 = and i64 %ptrint3, 63, !dbg !18
#   %maskcond5 = icmp eq i64 %maskedptr4, 0, !dbg !18
#   tail call void @llvm.assume(i1 %maskcond5), !dbg !18
#   %14 = getelementptr inbounds %0, %0* %B76, i64 0, i32 4, !dbg !18
#   %matmul.B.shape = load i64*, i64** %14, align 8, !dbg !18
#   %15 = getelementptr inbounds %0, %0* %B76, i64 0, i32 5, !dbg !18
#   %matmul.B.strides = load i64*, i64** %15, align 8, !dbg !18
#   %16 = bitcast %0* %C77 to float**, !dbg !18
#   %C_void_ptr80 = load float*, float** %16, align 8, !dbg !18
#   %ptrint7 = ptrtoint float* %C_void_ptr80 to i64, !dbg !18
#   %maskedptr8 = and i64 %ptrint7, 63, !dbg !18
#   %maskcond9 = icmp eq i64 %maskedptr8, 0, !dbg !18
#   tail call void @llvm.assume(i1 %maskcond9), !dbg !18
#   %17 = getelementptr inbounds %0, %0* %C77, i64 0, i32 4, !dbg !18
#   %matmul.C.shape = load i64*, i64** %17, align 8, !dbg !18
#   %18 = getelementptr inbounds %0, %0* %C77, i64 0, i32 5, !dbg !18
#   %matmul.C.strides = load i64*, i64** %18, align 8, !dbg !18
#   switch i32 %A.code, label %assert_fail10 [
#     i32 13, label %assert_end11
#     i32 7, label %assert_end11
#     i32 4, label %assert_end11
#     i32 3, label %assert_end11
#   ], !dbg !18
#
# assert_fail10:                                    ; preds = %assert_end
#   %19 = load void (i8*)*, void (i8*)** @__TVMAPISetLastError, align 8, !dbg !18, !tbaa !20
#   tail call void %19(i8* getelementptr inbounds ([108 x i8], [108 x i8]* @.str.1, i64 0, i64 0)), !dbg !18
#   ret i32 -1, !dbg !18
#
# assert_end11:                                     ; preds = %assert_end, %assert_end, %assert_end, %assert_end
#   switch i32 %B.code, label %assert_fail12 [
#     i32 13, label %assert_end13
#     i32 7, label %assert_end13
#     i32 4, label %assert_end13
#     i32 3, label %assert_end13
#   ], !dbg !18
#
# assert_fail12:                                    ; preds = %assert_end11
#   %20 = load void (i8*)*, void (i8*)** @__TVMAPISetLastError, align 8, !dbg !18, !tbaa !20
#   tail call void %20(i8* getelementptr inbounds ([108 x i8], [108 x i8]* @.str.2, i64 0, i64 0)), !dbg !18
#   ret i32 -1, !dbg !18
#
# assert_end13:                                     ; preds = %assert_end11, %assert_end11, %assert_end11, %assert_end11
#   switch i32 %C.code, label %assert_fail14 [
#     i32 13, label %assert_end15
#     i32 7, label %assert_end15
#     i32 4, label %assert_end15
#     i32 3, label %assert_end15
#   ], !dbg !18
#
# assert_fail14:                                    ; preds = %assert_end13
#   %21 = load void (i8*)*, void (i8*)** @__TVMAPISetLastError, align 8, !dbg !18, !tbaa !20
#   tail call void %21(i8* getelementptr inbounds ([108 x i8], [108 x i8]* @.str.3, i64 0, i64 0)), !dbg !18
#   ret i32 -1, !dbg !18
#
# assert_end15:                                     ; preds = %assert_end13, %assert_end13, %assert_end13, %assert_end13
#   %22 = getelementptr inbounds %0, %0* %A75, i64 0, i32 2, !dbg !18
#   %23 = load i32, i32* %22, align 4, !dbg !18
#   %24 = icmp eq i32 %23, 2, !dbg !18
#   br i1 %24, label %assert_end19, label %assert_fail16, !dbg !18, !prof !19
#
# assert_fail16:                                    ; preds = %assert_end15
#   %25 = load void (i8*)*, void (i8*)** @__TVMAPISetLastError, align 8, !dbg !18, !tbaa !20
#   tail call void %25(i8* getelementptr inbounds ([91 x i8], [91 x i8]* @.str.4, i64 0, i64 0)), !dbg !18
#   ret i32 -1, !dbg !18
#
# assert_end19:                                     ; preds = %assert_end15
#   %26 = getelementptr inbounds %0, %0* %A75, i64 0, i32 3, i32 2, !dbg !18
#   %27 = load i16, i16* %26, align 2, !dbg !18
#   %28 = icmp eq i16 %27, 1, !dbg !18
#   %29 = getelementptr inbounds %0, %0* %A75, i64 0, i32 3, i32 1, !dbg !18
#   %30 = load i8, i8* %29, align 1, !dbg !18
#   %31 = icmp eq i8 %30, 32, !dbg !18
#   %32 = getelementptr inbounds %0, %0* %A75, i64 0, i32 3, i32 0, !dbg !18
#   %33 = load i8, i8* %32, align 1, !dbg !18
#   %34 = icmp eq i8 %33, 2, !dbg !18
#   %35 = and i1 %31, %34, !dbg !18
#   %36 = and i1 %28, %35, !dbg !18
#   br i1 %36, label %assert_end21, label %assert_fail20, !dbg !18, !prof !19
#
# assert_fail20:                                    ; preds = %assert_end19
#   %37 = load void (i8*)*, void (i8*)** @__TVMAPISetLastError, align 8, !dbg !18, !tbaa !20
#   tail call void %37(i8* getelementptr inbounds ([213 x i8], [213 x i8]* @.str.5, i64 0, i64 0)), !dbg !18
#   ret i32 -1, !dbg !18
#
# assert_end21:                                     ; preds = %assert_end19
#   %38 = load i64, i64* %matmul.A.shape, align 8, !dbg !18, !tbaa !39
#   %39 = trunc i64 %38 to i32, !dbg !18
#   %40 = icmp eq i32 %39, 256, !dbg !18
#   br i1 %40, label %assert_end23, label %assert_fail22, !dbg !18, !prof !19
#
# assert_fail22:                                    ; preds = %assert_end21
#   %41 = load void (i8*)*, void (i8*)** @__TVMAPISetLastError, align 8, !dbg !18, !tbaa !20
#   tail call void %41(i8* getelementptr inbounds ([156 x i8], [156 x i8]* @.str.6, i64 0, i64 0)), !dbg !18
#   ret i32 -1, !dbg !18
#
# assert_end23:                                     ; preds = %assert_end21
#   %42 = getelementptr inbounds i64, i64* %matmul.A.shape, i64 1, !dbg !18
#   %43 = load i64, i64* %42, align 8, !dbg !18, !tbaa !49
#   %44 = trunc i64 %43 to i32, !dbg !18
#   %45 = icmp eq i32 %44, 256, !dbg !18
#   br i1 %45, label %assert_end25, label %assert_fail24, !dbg !18, !prof !19
#
# assert_fail24:                                    ; preds = %assert_end23
#   %46 = load void (i8*)*, void (i8*)** @__TVMAPISetLastError, align 8, !dbg !18, !tbaa !20
#   tail call void %46(i8* getelementptr inbounds ([156 x i8], [156 x i8]* @.str.7, i64 0, i64 0)), !dbg !18
#   ret i32 -1, !dbg !18
#
# assert_end25:                                     ; preds = %assert_end23
#   %47 = icmp eq i64* %matmul.A.strides, null, !dbg !18
#   br i1 %47, label %if_end, label %if_then, !dbg !18, !prof !51
#
# if_then:                                          ; preds = %assert_end25
#   %48 = load i64, i64* %matmul.A.strides, align 8, !dbg !18, !tbaa !52
#   %49 = trunc i64 %48 to i32, !dbg !18
#   %50 = icmp eq i32 %49, 256, !dbg !18
#   %51 = getelementptr inbounds i64, i64* %matmul.A.strides, i64 1, !dbg !18
#   %52 = load i64, i64* %51, align 8, !dbg !18, !tbaa !62
#   %53 = trunc i64 %52 to i32, !dbg !18
#   %54 = icmp eq i32 %53, 1, !dbg !18
#   %55 = and i1 %50, %54, !dbg !18
#   br i1 %55, label %if_end, label %assert_fail26, !dbg !18, !prof !19
#
# if_end:                                           ; preds = %assert_end25, %if_then
#   %56 = getelementptr inbounds %0, %0* %A75, i64 0, i32 6, !dbg !18
#   %57 = load i64, i64* %56, align 8, !dbg !18
#   %58 = icmp eq i64 %57, 0, !dbg !18
#   br i1 %58, label %assert_end29, label %assert_fail28, !dbg !18, !prof !19
#
# assert_fail26:                                    ; preds = %if_then
#   %59 = load void (i8*)*, void (i8*)** @__TVMAPISetLastError, align 8, !dbg !18, !tbaa !20
#   tail call void %59(i8* getelementptr inbounds ([151 x i8], [151 x i8]* @.str.8, i64 0, i64 0)), !dbg !18
#   ret i32 -1, !dbg !18
#
# assert_fail28:                                    ; preds = %if_end
#   %60 = load void (i8*)*, void (i8*)** @__TVMAPISetLastError, align 8, !dbg !18, !tbaa !20
#   tail call void %60(i8* getelementptr inbounds ([177 x i8], [177 x i8]* @.str.9, i64 0, i64 0)), !dbg !18
#   ret i32 -1, !dbg !18
#
# assert_end29:                                     ; preds = %if_end
#   %61 = getelementptr inbounds %0, %0* %A75, i64 0, i32 1, i32 0, !dbg !18
#   %62 = load i32, i32* %61, align 4, !dbg !18
#   %63 = icmp eq i32 %62, 1, !dbg !18
#   br i1 %63, label %assert_end31, label %assert_fail30, !dbg !18, !prof !19
#
# assert_fail30:                                    ; preds = %assert_end29
#   %64 = load void (i8*)*, void (i8*)** @__TVMAPISetLastError, align 8, !dbg !18, !tbaa !20
#   tail call void %64(i8* getelementptr inbounds ([157 x i8], [157 x i8]* @.str.10, i64 0, i64 0)), !dbg !18
#   ret i32 -1, !dbg !18
#
# assert_end31:                                     ; preds = %assert_end29
#   %65 = getelementptr inbounds %0, %0* %B76, i64 0, i32 2, !dbg !18
#   %66 = load i32, i32* %65, align 4, !dbg !18
#   %67 = icmp eq i32 %66, 2, !dbg !18
#   br i1 %67, label %assert_end35, label %assert_fail32, !dbg !18, !prof !19
#
# assert_fail32:                                    ; preds = %assert_end31
#   %68 = load void (i8*)*, void (i8*)** @__TVMAPISetLastError, align 8, !dbg !18, !tbaa !20
#   tail call void %68(i8* getelementptr inbounds ([91 x i8], [91 x i8]* @.str.11, i64 0, i64 0)), !dbg !18
#   ret i32 -1, !dbg !18
#
# assert_end35:                                     ; preds = %assert_end31
#   %69 = getelementptr inbounds %0, %0* %B76, i64 0, i32 3, i32 2, !dbg !18
#   %70 = load i16, i16* %69, align 2, !dbg !18
#   %71 = icmp eq i16 %70, 1, !dbg !18
#   %72 = getelementptr inbounds %0, %0* %B76, i64 0, i32 3, i32 1, !dbg !18
#   %73 = load i8, i8* %72, align 1, !dbg !18
#   %74 = icmp eq i8 %73, 32, !dbg !18
#   %75 = getelementptr inbounds %0, %0* %B76, i64 0, i32 3, i32 0, !dbg !18
#   %76 = load i8, i8* %75, align 1, !dbg !18
#   %77 = icmp eq i8 %76, 2, !dbg !18
#   %78 = and i1 %74, %77, !dbg !18
#   %79 = and i1 %71, %78, !dbg !18
#   br i1 %79, label %assert_end37, label %assert_fail36, !dbg !18, !prof !19
#
# assert_fail36:                                    ; preds = %assert_end35
#   %80 = load void (i8*)*, void (i8*)** @__TVMAPISetLastError, align 8, !dbg !18, !tbaa !20
#   tail call void %80(i8* getelementptr inbounds ([213 x i8], [213 x i8]* @.str.12, i64 0, i64 0)), !dbg !18
#   ret i32 -1, !dbg !18
#
# assert_end37:                                     ; preds = %assert_end35
#   %81 = load i64, i64* %matmul.B.shape, align 8, !dbg !18, !tbaa !64
#   %82 = trunc i64 %81 to i32, !dbg !18
#   %83 = icmp eq i32 %82, 256, !dbg !18
#   br i1 %83, label %assert_end39, label %assert_fail38, !dbg !18, !prof !19
#
# assert_fail38:                                    ; preds = %assert_end37
#   %84 = load void (i8*)*, void (i8*)** @__TVMAPISetLastError, align 8, !dbg !18, !tbaa !20
#   tail call void %84(i8* getelementptr inbounds ([156 x i8], [156 x i8]* @.str.13, i64 0, i64 0)), !dbg !18
#   ret i32 -1, !dbg !18
#
# assert_end39:                                     ; preds = %assert_end37
#   %85 = getelementptr inbounds i64, i64* %matmul.B.shape, i64 1, !dbg !18
#   %86 = load i64, i64* %85, align 8, !dbg !18, !tbaa !74
#   %87 = trunc i64 %86 to i32, !dbg !18
#   %88 = icmp eq i32 %87, 256, !dbg !18
#   br i1 %88, label %assert_end41, label %assert_fail40, !dbg !18, !prof !19
#
# assert_fail40:                                    ; preds = %assert_end39
#   %89 = load void (i8*)*, void (i8*)** @__TVMAPISetLastError, align 8, !dbg !18, !tbaa !20
#   tail call void %89(i8* getelementptr inbounds ([156 x i8], [156 x i8]* @.str.14, i64 0, i64 0)), !dbg !18
#   ret i32 -1, !dbg !18
#
# assert_end41:                                     ; preds = %assert_end39
#   %90 = icmp eq i64* %matmul.B.strides, null, !dbg !18
#   br i1 %90, label %if_end43, label %if_then42, !dbg !18, !prof !51
#
# if_then42:                                        ; preds = %assert_end41
#   %91 = load i64, i64* %matmul.B.strides, align 8, !dbg !18, !tbaa !76
#   %92 = trunc i64 %91 to i32, !dbg !18
#   %93 = icmp eq i32 %92, 256, !dbg !18
#   %94 = getelementptr inbounds i64, i64* %matmul.B.strides, i64 1, !dbg !18
#   %95 = load i64, i64* %94, align 8, !dbg !18, !tbaa !86
#   %96 = trunc i64 %95 to i32, !dbg !18
#   %97 = icmp eq i32 %96, 1, !dbg !18
#   %98 = and i1 %93, %97, !dbg !18
#   br i1 %98, label %if_end43, label %assert_fail44, !dbg !18, !prof !19
#
# if_end43:                                         ; preds = %assert_end41, %if_then42
#   %99 = getelementptr inbounds %0, %0* %B76, i64 0, i32 6, !dbg !18
#   %100 = load i64, i64* %99, align 8, !dbg !18
#   %101 = icmp eq i64 %100, 0, !dbg !18
#   br i1 %101, label %assert_end47, label %assert_fail46, !dbg !18, !prof !19
#
# assert_fail44:                                    ; preds = %if_then42
#   %102 = load void (i8*)*, void (i8*)** @__TVMAPISetLastError, align 8, !dbg !18, !tbaa !20
#   tail call void %102(i8* getelementptr inbounds ([151 x i8], [151 x i8]* @.str.15, i64 0, i64 0)), !dbg !18
#   ret i32 -1, !dbg !18
#
# assert_fail46:                                    ; preds = %if_end43
#   %103 = load void (i8*)*, void (i8*)** @__TVMAPISetLastError, align 8, !dbg !18, !tbaa !20
#   tail call void %103(i8* getelementptr inbounds ([177 x i8], [177 x i8]* @.str.16, i64 0, i64 0)), !dbg !18
#   ret i32 -1, !dbg !18
#
# assert_end47:                                     ; preds = %if_end43
#   %104 = getelementptr inbounds %0, %0* %B76, i64 0, i32 1, i32 0, !dbg !18
#   %105 = load i32, i32* %104, align 4, !dbg !18
#   %106 = icmp eq i32 %105, 1, !dbg !18
#   br i1 %106, label %assert_end49, label %assert_fail48, !dbg !18, !prof !19
#
# assert_fail48:                                    ; preds = %assert_end47
#   %107 = load void (i8*)*, void (i8*)** @__TVMAPISetLastError, align 8, !dbg !18, !tbaa !20
#   tail call void %107(i8* getelementptr inbounds ([157 x i8], [157 x i8]* @.str.17, i64 0, i64 0)), !dbg !18
#   ret i32 -1, !dbg !18
#
# assert_end49:                                     ; preds = %assert_end47
#   %108 = getelementptr inbounds %0, %0* %B76, i64 0, i32 1, i32 1, !dbg !18
#   %109 = load i32, i32* %108, align 4, !dbg !18
#   %110 = icmp eq i32 %dev_id, %109, !dbg !18
#   br i1 %110, label %assert_end51, label %assert_fail50, !dbg !18, !prof !19
#
# assert_fail50:                                    ; preds = %assert_end49
#   %111 = load void (i8*)*, void (i8*)** @__TVMAPISetLastError, align 8, !dbg !18, !tbaa !20
#   tail call void %111(i8* getelementptr inbounds ([163 x i8], [163 x i8]* @.str.18, i64 0, i64 0)), !dbg !18
#   ret i32 -1, !dbg !18
#
# assert_end51:                                     ; preds = %assert_end49
#   %112 = getelementptr inbounds %0, %0* %C77, i64 0, i32 2, !dbg !18
#   %113 = load i32, i32* %112, align 4, !dbg !18
#   %114 = icmp eq i32 %113, 2, !dbg !18
#   br i1 %114, label %assert_end55, label %assert_fail52, !dbg !18, !prof !19
#
# assert_fail52:                                    ; preds = %assert_end51
#   %115 = load void (i8*)*, void (i8*)** @__TVMAPISetLastError, align 8, !dbg !18, !tbaa !20
#   tail call void %115(i8* getelementptr inbounds ([91 x i8], [91 x i8]* @.str.19, i64 0, i64 0)), !dbg !18
#   ret i32 -1, !dbg !18
#
# assert_end55:                                     ; preds = %assert_end51
#   %116 = getelementptr inbounds %0, %0* %C77, i64 0, i32 3, i32 2, !dbg !18
#   %117 = load i16, i16* %116, align 2, !dbg !18
#   %118 = icmp eq i16 %117, 1, !dbg !18
#   %119 = getelementptr inbounds %0, %0* %C77, i64 0, i32 3, i32 1, !dbg !18
#   %120 = load i8, i8* %119, align 1, !dbg !18
#   %121 = icmp eq i8 %120, 32, !dbg !18
#   %122 = getelementptr inbounds %0, %0* %C77, i64 0, i32 3, i32 0, !dbg !18
#   %123 = load i8, i8* %122, align 1, !dbg !18
#   %124 = icmp eq i8 %123, 2, !dbg !18
#   %125 = and i1 %121, %124, !dbg !18
#   %126 = and i1 %118, %125, !dbg !18
#   br i1 %126, label %assert_end57, label %assert_fail56, !dbg !18, !prof !19
#
# assert_fail56:                                    ; preds = %assert_end55
#   %127 = load void (i8*)*, void (i8*)** @__TVMAPISetLastError, align 8, !dbg !18, !tbaa !20
#   tail call void %127(i8* getelementptr inbounds ([213 x i8], [213 x i8]* @.str.20, i64 0, i64 0)), !dbg !18
#   ret i32 -1, !dbg !18
#
# assert_end57:                                     ; preds = %assert_end55
#   %128 = load i64, i64* %matmul.C.shape, align 8, !dbg !18, !tbaa !88
#   %129 = trunc i64 %128 to i32, !dbg !18
#   %130 = icmp eq i32 %129, 256, !dbg !18
#   br i1 %130, label %assert_end59, label %assert_fail58, !dbg !18, !prof !19
#
# assert_fail58:                                    ; preds = %assert_end57
#   %131 = load void (i8*)*, void (i8*)** @__TVMAPISetLastError, align 8, !dbg !18, !tbaa !20
#   tail call void %131(i8* getelementptr inbounds ([156 x i8], [156 x i8]* @.str.21, i64 0, i64 0)), !dbg !18
#   ret i32 -1, !dbg !18
#
# assert_end59:                                     ; preds = %assert_end57
#   %132 = getelementptr inbounds i64, i64* %matmul.C.shape, i64 1, !dbg !18
#   %133 = load i64, i64* %132, align 8, !dbg !18, !tbaa !98
#   %134 = trunc i64 %133 to i32, !dbg !18
#   %135 = icmp eq i32 %134, 256, !dbg !18
#   br i1 %135, label %assert_end61, label %assert_fail60, !dbg !18, !prof !19
#
# assert_fail60:                                    ; preds = %assert_end59
#   %136 = load void (i8*)*, void (i8*)** @__TVMAPISetLastError, align 8, !dbg !18, !tbaa !20
#   tail call void %136(i8* getelementptr inbounds ([156 x i8], [156 x i8]* @.str.22, i64 0, i64 0)), !dbg !18
#   ret i32 -1, !dbg !18
#
# assert_end61:                                     ; preds = %assert_end59
#   %137 = icmp eq i64* %matmul.C.strides, null, !dbg !18
#   br i1 %137, label %if_end63, label %if_then62, !dbg !18, !prof !51
#
# if_then62:                                        ; preds = %assert_end61
#   %138 = load i64, i64* %matmul.C.strides, align 8, !dbg !18, !tbaa !100
#   %139 = trunc i64 %138 to i32, !dbg !18
#   %140 = icmp eq i32 %139, 256, !dbg !18
#   %141 = getelementptr inbounds i64, i64* %matmul.C.strides, i64 1, !dbg !18
#   %142 = load i64, i64* %141, align 8, !dbg !18, !tbaa !110
#   %143 = trunc i64 %142 to i32, !dbg !18
#   %144 = icmp eq i32 %143, 1, !dbg !18
#   %145 = and i1 %140, %144, !dbg !18
#   br i1 %145, label %if_end63, label %assert_fail64, !dbg !18, !prof !19
#
# if_end63:                                         ; preds = %assert_end61, %if_then62
#   %146 = getelementptr inbounds %0, %0* %C77, i64 0, i32 6, !dbg !18
#   %147 = load i64, i64* %146, align 8, !dbg !18
#   %148 = icmp eq i64 %147, 0, !dbg !18
#   br i1 %148, label %assert_end67, label %assert_fail66, !dbg !18, !prof !19
#
# assert_fail64:                                    ; preds = %if_then62
#   %149 = load void (i8*)*, void (i8*)** @__TVMAPISetLastError, align 8, !dbg !18, !tbaa !20
#   tail call void %149(i8* getelementptr inbounds ([151 x i8], [151 x i8]* @.str.23, i64 0, i64 0)), !dbg !18
#   ret i32 -1, !dbg !18
#
# assert_fail66:                                    ; preds = %if_end63
#   %150 = load void (i8*)*, void (i8*)** @__TVMAPISetLastError, align 8, !dbg !18, !tbaa !20
#   tail call void %150(i8* getelementptr inbounds ([177 x i8], [177 x i8]* @.str.24, i64 0, i64 0)), !dbg !18
#   ret i32 -1, !dbg !18
#
# assert_end67:                                     ; preds = %if_end63
#   %151 = getelementptr inbounds %0, %0* %C77, i64 0, i32 1, i32 0, !dbg !18
#   %152 = load i32, i32* %151, align 4, !dbg !18
#   %153 = icmp eq i32 %152, 1, !dbg !18
#   br i1 %153, label %assert_end69, label %assert_fail68, !dbg !18, !prof !19
#
# assert_fail68:                                    ; preds = %assert_end67
#   %154 = load void (i8*)*, void (i8*)** @__TVMAPISetLastError, align 8, !dbg !18, !tbaa !20
#   tail call void %154(i8* getelementptr inbounds ([157 x i8], [157 x i8]* @.str.25, i64 0, i64 0)), !dbg !18
#   ret i32 -1, !dbg !18
#
# assert_end69:                                     ; preds = %assert_end67
#   %155 = getelementptr inbounds %0, %0* %C77, i64 0, i32 1, i32 1, !dbg !18
#   %156 = load i32, i32* %155, align 4, !dbg !18
#   %157 = icmp eq i32 %dev_id, %156, !dbg !18
#   br i1 %157, label %assert_end71, label %assert_fail70, !dbg !18, !prof !19
#
# assert_fail70:                                    ; preds = %assert_end69
#   %158 = load void (i8*)*, void (i8*)** @__TVMAPISetLastError, align 8, !dbg !18, !tbaa !20
#   tail call void %158(i8* getelementptr inbounds ([163 x i8], [163 x i8]* @.str.26, i64 0, i64 0)), !dbg !18
#   ret i32 -1, !dbg !18
#
# assert_end71:                                     ; preds = %assert_end69
#   tail call fastcc void @matmul_compute_(float* %C_void_ptr80, float* %A_void_ptr78, float* %B_void_ptr79), !dbg !18
#   ret i32 0, !dbg !18
# }
#
# ; Function Attrs: nounwind willreturn
# declare void @llvm.assume(i1) #1
#
# ; Function Attrs: nofree noinline nounwind
# define internal fastcc void @matmul_compute_(float* noalias nocapture align 64 %0, float* noalias nocapture readonly align 64 %1, float* noalias nocapture readonly align 64 %2) unnamed_addr #2 {
# entry:
#   %scevgep221 = getelementptr float, float* %2, i64 24
#   %scevgep230 = getelementptr float, float* %2, i64 56
#   %scevgep238 = getelementptr float, float* %2, i64 88
#   %scevgep246 = getelementptr float, float* %2, i64 120
#   %scevgep254 = getelementptr float, float* %2, i64 152
#   %scevgep262 = getelementptr float, float* %2, i64 184
#   %scevgep270 = getelementptr float, float* %2, i64 216
#   %scevgep278 = getelementptr float, float* %2, i64 248
#   br label %for_begin_n.outer.preheader
#
# for_begin_n.outer.preheader:                      ; preds = %for_end_k.7, %entry
#   %lsr.iv227 = phi float* [ %scevgep228, %for_end_k.7 ], [ %1, %entry ]
#   %indvar = phi i64 [ 0, %entry ], [ %indvar.next, %for_end_k.7 ]
#   %3 = shl nsw i64 %indvar, 8
#   %scevgep = getelementptr float, float* %0, i64 %3
#   %scevgep8 = bitcast float* %scevgep to i8*
#   call void @llvm.memset.p0i8.i64(i8* nonnull align 64 dereferenceable(128) %scevgep8, i8 0, i64 128, i1 false)
#   %4 = getelementptr inbounds float, float* %0, i64 %3
#   %5 = bitcast float* %4 to <8 x float>*
#   %6 = or i64 %3, 8
#   %7 = getelementptr inbounds float, float* %0, i64 %6
#   %8 = bitcast float* %7 to <8 x float>*
#   %9 = or i64 %3, 16
#   %10 = getelementptr inbounds float, float* %0, i64 %9
#   %11 = bitcast float* %10 to <8 x float>*
#   %12 = or i64 %3, 24
#   %13 = getelementptr inbounds float, float* %0, i64 %12
#   %14 = bitcast float* %13 to <8 x float>*
#   %.promoted = load <8 x float>, <8 x float>* %5, align 64, !tbaa !112
#   %.promoted128 = load <8 x float>, <8 x float>* %8, align 32, !tbaa !112
#   %.promoted131 = load <8 x float>, <8 x float>* %11, align 64, !tbaa !112
#   %.promoted134 = load <8 x float>, <8 x float>* %14, align 32, !tbaa !112
#   br label %for_begin_n.inner.preheader
#
# for_end_m.outer:                                  ; preds = %for_end_k.7
#   ret void
#
# for_begin_n.inner.preheader:                      ; preds = %for_begin_n.inner.preheader, %for_begin_n.outer.preheader
#   %lsr.iv = phi float* [ %scevgep222, %for_begin_n.inner.preheader ], [ %scevgep221, %for_begin_n.outer.preheader ]
#   %wide.load124.3135 = phi <8 x float> [ %.promoted134, %for_begin_n.outer.preheader ], [ %19, %for_begin_n.inner.preheader ]
#   %wide.load124.2132 = phi <8 x float> [ %.promoted131, %for_begin_n.outer.preheader ], [ %18, %for_begin_n.inner.preheader ]
#   %wide.load124.1129 = phi <8 x float> [ %.promoted128, %for_begin_n.outer.preheader ], [ %17, %for_begin_n.inner.preheader ]
#   %wide.load124127 = phi <8 x float> [ %.promoted, %for_begin_n.outer.preheader ], [ %16, %for_begin_n.inner.preheader ]
#   %indvars.iv10 = phi i64 [ 0, %for_begin_n.outer.preheader ], [ %indvars.iv.next11, %for_begin_n.inner.preheader ]
#   %lsr.iv223 = bitcast float* %lsr.iv to <8 x float>*
#   %scevgep229 = getelementptr float, float* %lsr.iv227, i64 %indvars.iv10
#   %15 = load float, float* %scevgep229, align 4, !tbaa !114
#   %broadcast.splatinsert125 = insertelement <8 x float> undef, float %15, i32 0
#   %broadcast.splat126 = shufflevector <8 x float> %broadcast.splatinsert125, <8 x float> undef, <8 x i32> zeroinitializer
#   %scevgep226 = getelementptr <8 x float>, <8 x float>* %lsr.iv223, i64 -3
#   %wide.load123 = load <8 x float>, <8 x float>* %scevgep226, align 64, !tbaa !116
#   %16 = call <8 x float> @llvm.fmuladd.v8f32(<8 x float> %broadcast.splat126, <8 x float> %wide.load123, <8 x float> %wide.load124127)
#   %scevgep225 = getelementptr <8 x float>, <8 x float>* %lsr.iv223, i64 -2
#   %wide.load123.1 = load <8 x float>, <8 x float>* %scevgep225, align 32, !tbaa !116
#   %17 = call <8 x float> @llvm.fmuladd.v8f32(<8 x float> %broadcast.splat126, <8 x float> %wide.load123.1, <8 x float> %wide.load124.1129)
#   %scevgep224 = getelementptr <8 x float>, <8 x float>* %lsr.iv223, i64 -1
#   %wide.load123.2 = load <8 x float>, <8 x float>* %scevgep224, align 64, !tbaa !116
#   %18 = call <8 x float> @llvm.fmuladd.v8f32(<8 x float> %broadcast.splat126, <8 x float> %wide.load123.2, <8 x float> %wide.load124.2132)
#   %wide.load123.3 = load <8 x float>, <8 x float>* %lsr.iv223, align 32, !tbaa !116
#   %19 = call <8 x float> @llvm.fmuladd.v8f32(<8 x float> %broadcast.splat126, <8 x float> %wide.load123.3, <8 x float> %wide.load124.3135)
#   %indvars.iv.next11 = add nuw nsw i64 %indvars.iv10, 1
#   %scevgep222 = getelementptr float, float* %lsr.iv, i64 256
#   %exitcond12 = icmp eq i64 %indvars.iv.next11, 256
#   br i1 %exitcond12, label %for_end_k, label %for_begin_n.inner.preheader, !prof !51
#
# for_end_k:                                        ; preds = %for_begin_n.inner.preheader
#   %sunkaddr = mul i64 %3, 4
#   %20 = bitcast float* %0 to i8*
#   %sunkaddr286 = getelementptr inbounds i8, i8* %20, i64 %sunkaddr
#   %21 = bitcast i8* %sunkaddr286 to <8 x float>*
#   store <8 x float> %16, <8 x float>* %21, align 64, !tbaa !112
#   %sunkaddr287 = mul i64 %6, 4
#   %22 = bitcast float* %0 to i8*
#   %sunkaddr288 = getelementptr inbounds i8, i8* %22, i64 %sunkaddr287
#   %23 = bitcast i8* %sunkaddr288 to <8 x float>*
#   store <8 x float> %17, <8 x float>* %23, align 32, !tbaa !112
#   %sunkaddr289 = mul i64 %9, 4
#   %24 = bitcast float* %0 to i8*
#   %sunkaddr290 = getelementptr inbounds i8, i8* %24, i64 %sunkaddr289
#   %25 = bitcast i8* %sunkaddr290 to <8 x float>*
#   store <8 x float> %18, <8 x float>* %25, align 64, !tbaa !112
#   %sunkaddr291 = mul i64 %12, 4
#   %26 = bitcast float* %0 to i8*
#   %sunkaddr292 = getelementptr inbounds i8, i8* %26, i64 %sunkaddr291
#   %27 = bitcast i8* %sunkaddr292 to <8 x float>*
#   store <8 x float> %19, <8 x float>* %27, align 32, !tbaa !112
#   %28 = or i64 %3, 32
#   %scevgep.1 = getelementptr float, float* %0, i64 %28
#   %scevgep8.1 = bitcast float* %scevgep.1 to i8*
#   call void @llvm.memset.p0i8.i64(i8* nonnull align 64 dereferenceable(128) %scevgep8.1, i8 0, i64 128, i1 false)
#   %29 = or i64 %3, 32
#   %30 = getelementptr inbounds float, float* %0, i64 %29
#   %31 = bitcast float* %30 to <8 x float>*
#   %32 = or i64 %3, 40
#   %33 = getelementptr inbounds float, float* %0, i64 %32
#   %34 = bitcast float* %33 to <8 x float>*
#   %35 = or i64 %3, 48
#   %36 = getelementptr inbounds float, float* %0, i64 %35
#   %37 = bitcast float* %36 to <8 x float>*
#   %38 = or i64 %3, 56
#   %39 = getelementptr inbounds float, float* %0, i64 %38
#   %40 = bitcast float* %39 to <8 x float>*
#   %.promoted137 = load <8 x float>, <8 x float>* %31, align 64, !tbaa !112
#   %.promoted140 = load <8 x float>, <8 x float>* %34, align 32, !tbaa !112
#   %.promoted143 = load <8 x float>, <8 x float>* %37, align 64, !tbaa !112
#   %.promoted146 = load <8 x float>, <8 x float>* %40, align 32, !tbaa !112
#   br label %for_begin_n.inner.preheader.1
#
# for_begin_n.inner.preheader.1:                    ; preds = %for_begin_n.inner.preheader.1, %for_end_k
#   %lsr.iv231 = phi float* [ %scevgep232, %for_begin_n.inner.preheader.1 ], [ %scevgep230, %for_end_k ]
#   %wide.load109.3147 = phi <8 x float> [ %.promoted146, %for_end_k ], [ %45, %for_begin_n.inner.preheader.1 ]
#   %wide.load109.2144 = phi <8 x float> [ %.promoted143, %for_end_k ], [ %44, %for_begin_n.inner.preheader.1 ]
#   %wide.load109.1141 = phi <8 x float> [ %.promoted140, %for_end_k ], [ %43, %for_begin_n.inner.preheader.1 ]
#   %wide.load109138 = phi <8 x float> [ %.promoted137, %for_end_k ], [ %42, %for_begin_n.inner.preheader.1 ]
#   %indvars.iv10.1 = phi i64 [ 0, %for_end_k ], [ %indvars.iv.next11.1, %for_begin_n.inner.preheader.1 ]
#   %lsr.iv231233 = bitcast float* %lsr.iv231 to <8 x float>*
#   %scevgep237 = getelementptr float, float* %lsr.iv227, i64 %indvars.iv10.1
#   %41 = load float, float* %scevgep237, align 4, !tbaa !114
#   %broadcast.splatinsert110 = insertelement <8 x float> undef, float %41, i32 0
#   %broadcast.splat111 = shufflevector <8 x float> %broadcast.splatinsert110, <8 x float> undef, <8 x i32> zeroinitializer
#   %scevgep236 = getelementptr <8 x float>, <8 x float>* %lsr.iv231233, i64 -3
#   %wide.load108 = load <8 x float>, <8 x float>* %scevgep236, align 64, !tbaa !116
#   %42 = call <8 x float> @llvm.fmuladd.v8f32(<8 x float> %broadcast.splat111, <8 x float> %wide.load108, <8 x float> %wide.load109138)
#   %scevgep235 = getelementptr <8 x float>, <8 x float>* %lsr.iv231233, i64 -2
#   %wide.load108.1 = load <8 x float>, <8 x float>* %scevgep235, align 32, !tbaa !116
#   %43 = call <8 x float> @llvm.fmuladd.v8f32(<8 x float> %broadcast.splat111, <8 x float> %wide.load108.1, <8 x float> %wide.load109.1141)
#   %scevgep234 = getelementptr <8 x float>, <8 x float>* %lsr.iv231233, i64 -1
#   %wide.load108.2 = load <8 x float>, <8 x float>* %scevgep234, align 64, !tbaa !116
#   %44 = call <8 x float> @llvm.fmuladd.v8f32(<8 x float> %broadcast.splat111, <8 x float> %wide.load108.2, <8 x float> %wide.load109.2144)
#   %wide.load108.3 = load <8 x float>, <8 x float>* %lsr.iv231233, align 32, !tbaa !116
#   %45 = call <8 x float> @llvm.fmuladd.v8f32(<8 x float> %broadcast.splat111, <8 x float> %wide.load108.3, <8 x float> %wide.load109.3147)
#   %indvars.iv.next11.1 = add nuw nsw i64 %indvars.iv10.1, 1
#   %scevgep232 = getelementptr float, float* %lsr.iv231, i64 256
#   %exitcond12.1 = icmp eq i64 %indvars.iv.next11.1, 256
#   br i1 %exitcond12.1, label %for_end_k.1, label %for_begin_n.inner.preheader.1, !prof !51
#
# for_end_k.1:                                      ; preds = %for_begin_n.inner.preheader.1
#   %sunkaddr293 = mul i64 %29, 4
#   %46 = bitcast float* %0 to i8*
#   %sunkaddr294 = getelementptr inbounds i8, i8* %46, i64 %sunkaddr293
#   %47 = bitcast i8* %sunkaddr294 to <8 x float>*
#   store <8 x float> %42, <8 x float>* %47, align 64, !tbaa !112
#   %sunkaddr295 = mul i64 %32, 4
#   %48 = bitcast float* %0 to i8*
#   %sunkaddr296 = getelementptr inbounds i8, i8* %48, i64 %sunkaddr295
#   %49 = bitcast i8* %sunkaddr296 to <8 x float>*
#   store <8 x float> %43, <8 x float>* %49, align 32, !tbaa !112
#   %sunkaddr297 = mul i64 %35, 4
#   %50 = bitcast float* %0 to i8*
#   %sunkaddr298 = getelementptr inbounds i8, i8* %50, i64 %sunkaddr297
#   %51 = bitcast i8* %sunkaddr298 to <8 x float>*
#   store <8 x float> %44, <8 x float>* %51, align 64, !tbaa !112
#   %sunkaddr299 = mul i64 %38, 4
#   %52 = bitcast float* %0 to i8*
#   %sunkaddr300 = getelementptr inbounds i8, i8* %52, i64 %sunkaddr299
#   %53 = bitcast i8* %sunkaddr300 to <8 x float>*
#   store <8 x float> %45, <8 x float>* %53, align 32, !tbaa !112
#   %54 = or i64 %3, 64
#   %scevgep.2 = getelementptr float, float* %0, i64 %54
#   %scevgep8.2 = bitcast float* %scevgep.2 to i8*
#   call void @llvm.memset.p0i8.i64(i8* nonnull align 64 dereferenceable(128) %scevgep8.2, i8 0, i64 128, i1 false)
#   %55 = or i64 %3, 64
#   %56 = getelementptr inbounds float, float* %0, i64 %55
#   %57 = bitcast float* %56 to <8 x float>*
#   %58 = or i64 %3, 72
#   %59 = getelementptr inbounds float, float* %0, i64 %58
#   %60 = bitcast float* %59 to <8 x float>*
#   %61 = or i64 %3, 80
#   %62 = getelementptr inbounds float, float* %0, i64 %61
#   %63 = bitcast float* %62 to <8 x float>*
#   %64 = or i64 %3, 88
#   %65 = getelementptr inbounds float, float* %0, i64 %64
#   %66 = bitcast float* %65 to <8 x float>*
#   %.promoted149 = load <8 x float>, <8 x float>* %57, align 64, !tbaa !112
#   %.promoted152 = load <8 x float>, <8 x float>* %60, align 32, !tbaa !112
#   %.promoted155 = load <8 x float>, <8 x float>* %63, align 64, !tbaa !112
#   %.promoted158 = load <8 x float>, <8 x float>* %66, align 32, !tbaa !112
#   br label %for_begin_n.inner.preheader.2
#
# for_begin_n.inner.preheader.2:                    ; preds = %for_begin_n.inner.preheader.2, %for_end_k.1
#   %lsr.iv239 = phi float* [ %scevgep240, %for_begin_n.inner.preheader.2 ], [ %scevgep238, %for_end_k.1 ]
#   %wide.load94.3159 = phi <8 x float> [ %.promoted158, %for_end_k.1 ], [ %71, %for_begin_n.inner.preheader.2 ]
#   %wide.load94.2156 = phi <8 x float> [ %.promoted155, %for_end_k.1 ], [ %70, %for_begin_n.inner.preheader.2 ]
#   %wide.load94.1153 = phi <8 x float> [ %.promoted152, %for_end_k.1 ], [ %69, %for_begin_n.inner.preheader.2 ]
#   %wide.load94150 = phi <8 x float> [ %.promoted149, %for_end_k.1 ], [ %68, %for_begin_n.inner.preheader.2 ]
#   %indvars.iv10.2 = phi i64 [ 0, %for_end_k.1 ], [ %indvars.iv.next11.2, %for_begin_n.inner.preheader.2 ]
#   %lsr.iv239241 = bitcast float* %lsr.iv239 to <8 x float>*
#   %scevgep245 = getelementptr float, float* %lsr.iv227, i64 %indvars.iv10.2
#   %67 = load float, float* %scevgep245, align 4, !tbaa !114
#   %broadcast.splatinsert95 = insertelement <8 x float> undef, float %67, i32 0
#   %broadcast.splat96 = shufflevector <8 x float> %broadcast.splatinsert95, <8 x float> undef, <8 x i32> zeroinitializer
#   %scevgep244 = getelementptr <8 x float>, <8 x float>* %lsr.iv239241, i64 -3
#   %wide.load93 = load <8 x float>, <8 x float>* %scevgep244, align 64, !tbaa !116
#   %68 = call <8 x float> @llvm.fmuladd.v8f32(<8 x float> %broadcast.splat96, <8 x float> %wide.load93, <8 x float> %wide.load94150)
#   %scevgep243 = getelementptr <8 x float>, <8 x float>* %lsr.iv239241, i64 -2
#   %wide.load93.1 = load <8 x float>, <8 x float>* %scevgep243, align 32, !tbaa !116
#   %69 = call <8 x float> @llvm.fmuladd.v8f32(<8 x float> %broadcast.splat96, <8 x float> %wide.load93.1, <8 x float> %wide.load94.1153)
#   %scevgep242 = getelementptr <8 x float>, <8 x float>* %lsr.iv239241, i64 -1
#   %wide.load93.2 = load <8 x float>, <8 x float>* %scevgep242, align 64, !tbaa !116
#   %70 = call <8 x float> @llvm.fmuladd.v8f32(<8 x float> %broadcast.splat96, <8 x float> %wide.load93.2, <8 x float> %wide.load94.2156)
#   %wide.load93.3 = load <8 x float>, <8 x float>* %lsr.iv239241, align 32, !tbaa !116
#   %71 = call <8 x float> @llvm.fmuladd.v8f32(<8 x float> %broadcast.splat96, <8 x float> %wide.load93.3, <8 x float> %wide.load94.3159)
#   %indvars.iv.next11.2 = add nuw nsw i64 %indvars.iv10.2, 1
#   %scevgep240 = getelementptr float, float* %lsr.iv239, i64 256
#   %exitcond12.2 = icmp eq i64 %indvars.iv.next11.2, 256
#   br i1 %exitcond12.2, label %for_end_k.2, label %for_begin_n.inner.preheader.2, !prof !51
#
# for_end_k.2:                                      ; preds = %for_begin_n.inner.preheader.2
#   %sunkaddr301 = mul i64 %55, 4
#   %72 = bitcast float* %0 to i8*
#   %sunkaddr302 = getelementptr inbounds i8, i8* %72, i64 %sunkaddr301
#   %73 = bitcast i8* %sunkaddr302 to <8 x float>*
#   store <8 x float> %68, <8 x float>* %73, align 64, !tbaa !112
#   %sunkaddr303 = mul i64 %58, 4
#   %74 = bitcast float* %0 to i8*
#   %sunkaddr304 = getelementptr inbounds i8, i8* %74, i64 %sunkaddr303
#   %75 = bitcast i8* %sunkaddr304 to <8 x float>*
#   store <8 x float> %69, <8 x float>* %75, align 32, !tbaa !112
#   %sunkaddr305 = mul i64 %61, 4
#   %76 = bitcast float* %0 to i8*
#   %sunkaddr306 = getelementptr inbounds i8, i8* %76, i64 %sunkaddr305
#   %77 = bitcast i8* %sunkaddr306 to <8 x float>*
#   store <8 x float> %70, <8 x float>* %77, align 64, !tbaa !112
#   %sunkaddr307 = mul i64 %64, 4
#   %78 = bitcast float* %0 to i8*
#   %sunkaddr308 = getelementptr inbounds i8, i8* %78, i64 %sunkaddr307
#   %79 = bitcast i8* %sunkaddr308 to <8 x float>*
#   store <8 x float> %71, <8 x float>* %79, align 32, !tbaa !112
#   %80 = or i64 %3, 96
#   %scevgep.3 = getelementptr float, float* %0, i64 %80
#   %scevgep8.3 = bitcast float* %scevgep.3 to i8*
#   call void @llvm.memset.p0i8.i64(i8* nonnull align 64 dereferenceable(128) %scevgep8.3, i8 0, i64 128, i1 false)
#   %81 = or i64 %3, 96
#   %82 = getelementptr inbounds float, float* %0, i64 %81
#   %83 = bitcast float* %82 to <8 x float>*
#   %84 = or i64 %3, 104
#   %85 = getelementptr inbounds float, float* %0, i64 %84
#   %86 = bitcast float* %85 to <8 x float>*
#   %87 = or i64 %3, 112
#   %88 = getelementptr inbounds float, float* %0, i64 %87
#   %89 = bitcast float* %88 to <8 x float>*
#   %90 = or i64 %3, 120
#   %91 = getelementptr inbounds float, float* %0, i64 %90
#   %92 = bitcast float* %91 to <8 x float>*
#   %.promoted161 = load <8 x float>, <8 x float>* %83, align 64, !tbaa !112
#   %.promoted164 = load <8 x float>, <8 x float>* %86, align 32, !tbaa !112
#   %.promoted167 = load <8 x float>, <8 x float>* %89, align 64, !tbaa !112
#   %.promoted170 = load <8 x float>, <8 x float>* %92, align 32, !tbaa !112
#   br label %for_begin_n.inner.preheader.3
#
# for_begin_n.inner.preheader.3:                    ; preds = %for_begin_n.inner.preheader.3, %for_end_k.2
#   %lsr.iv247 = phi float* [ %scevgep248, %for_begin_n.inner.preheader.3 ], [ %scevgep246, %for_end_k.2 ]
#   %wide.load79.3171 = phi <8 x float> [ %.promoted170, %for_end_k.2 ], [ %97, %for_begin_n.inner.preheader.3 ]
#   %wide.load79.2168 = phi <8 x float> [ %.promoted167, %for_end_k.2 ], [ %96, %for_begin_n.inner.preheader.3 ]
#   %wide.load79.1165 = phi <8 x float> [ %.promoted164, %for_end_k.2 ], [ %95, %for_begin_n.inner.preheader.3 ]
#   %wide.load79162 = phi <8 x float> [ %.promoted161, %for_end_k.2 ], [ %94, %for_begin_n.inner.preheader.3 ]
#   %indvars.iv10.3 = phi i64 [ 0, %for_end_k.2 ], [ %indvars.iv.next11.3, %for_begin_n.inner.preheader.3 ]
#   %lsr.iv247249 = bitcast float* %lsr.iv247 to <8 x float>*
#   %scevgep253 = getelementptr float, float* %lsr.iv227, i64 %indvars.iv10.3
#   %93 = load float, float* %scevgep253, align 4, !tbaa !114
#   %broadcast.splatinsert80 = insertelement <8 x float> undef, float %93, i32 0
#   %broadcast.splat81 = shufflevector <8 x float> %broadcast.splatinsert80, <8 x float> undef, <8 x i32> zeroinitializer
#   %scevgep252 = getelementptr <8 x float>, <8 x float>* %lsr.iv247249, i64 -3
#   %wide.load78 = load <8 x float>, <8 x float>* %scevgep252, align 64, !tbaa !116
#   %94 = call <8 x float> @llvm.fmuladd.v8f32(<8 x float> %broadcast.splat81, <8 x float> %wide.load78, <8 x float> %wide.load79162)
#   %scevgep251 = getelementptr <8 x float>, <8 x float>* %lsr.iv247249, i64 -2
#   %wide.load78.1 = load <8 x float>, <8 x float>* %scevgep251, align 32, !tbaa !116
#   %95 = call <8 x float> @llvm.fmuladd.v8f32(<8 x float> %broadcast.splat81, <8 x float> %wide.load78.1, <8 x float> %wide.load79.1165)
#   %scevgep250 = getelementptr <8 x float>, <8 x float>* %lsr.iv247249, i64 -1
#   %wide.load78.2 = load <8 x float>, <8 x float>* %scevgep250, align 64, !tbaa !116
#   %96 = call <8 x float> @llvm.fmuladd.v8f32(<8 x float> %broadcast.splat81, <8 x float> %wide.load78.2, <8 x float> %wide.load79.2168)
#   %wide.load78.3 = load <8 x float>, <8 x float>* %lsr.iv247249, align 32, !tbaa !116
#   %97 = call <8 x float> @llvm.fmuladd.v8f32(<8 x float> %broadcast.splat81, <8 x float> %wide.load78.3, <8 x float> %wide.load79.3171)
#   %indvars.iv.next11.3 = add nuw nsw i64 %indvars.iv10.3, 1
#   %scevgep248 = getelementptr float, float* %lsr.iv247, i64 256
#   %exitcond12.3 = icmp eq i64 %indvars.iv.next11.3, 256
#   br i1 %exitcond12.3, label %for_end_k.3, label %for_begin_n.inner.preheader.3, !prof !51
#
# for_end_k.3:                                      ; preds = %for_begin_n.inner.preheader.3
#   %sunkaddr309 = mul i64 %81, 4
#   %98 = bitcast float* %0 to i8*
#   %sunkaddr310 = getelementptr inbounds i8, i8* %98, i64 %sunkaddr309
#   %99 = bitcast i8* %sunkaddr310 to <8 x float>*
#   store <8 x float> %94, <8 x float>* %99, align 64, !tbaa !112
#   %sunkaddr311 = mul i64 %84, 4
#   %100 = bitcast float* %0 to i8*
#   %sunkaddr312 = getelementptr inbounds i8, i8* %100, i64 %sunkaddr311
#   %101 = bitcast i8* %sunkaddr312 to <8 x float>*
# ...
#   %187 = bitcast float* %186 to <8 x float>*
#   %188 = or i64 %3, 232
#   %189 = getelementptr inbounds float, float* %0, i64 %188
#   %190 = bitcast float* %189 to <8 x float>*
#   %191 = or i64 %3, 240
#   %192 = getelementptr inbounds float, float* %0, i64 %191
#   %193 = bitcast float* %192 to <8 x float>*
#   %194 = or i64 %3, 248
#   %195 = getelementptr inbounds float, float* %0, i64 %194
#   %196 = bitcast float* %195 to <8 x float>*
#   %.promoted209 = load <8 x float>, <8 x float>* %187, align 64, !tbaa !112
#   %.promoted212 = load <8 x float>, <8 x float>* %190, align 32, !tbaa !112
#   %.promoted215 = load <8 x float>, <8 x float>* %193, align 64, !tbaa !112
#   %.promoted218 = load <8 x float>, <8 x float>* %196, align 32, !tbaa !112
#   br label %for_begin_n.inner.preheader.7
#
# for_begin_n.inner.preheader.7:                    ; preds = %for_begin_n.inner.preheader.7, %for_end_k.6
#   %lsr.iv279 = phi float* [ %scevgep280, %for_begin_n.inner.preheader.7 ], [ %scevgep278, %for_end_k.6 ]
#   %wide.load19.3219 = phi <8 x float> [ %.promoted218, %for_end_k.6 ], [ %201, %for_begin_n.inner.preheader.7 ]
#   %wide.load19.2216 = phi <8 x float> [ %.promoted215, %for_end_k.6 ], [ %200, %for_begin_n.inner.preheader.7 ]
#   %wide.load19.1213 = phi <8 x float> [ %.promoted212, %for_end_k.6 ], [ %199, %for_begin_n.inner.preheader.7 ]
#   %wide.load19210 = phi <8 x float> [ %.promoted209, %for_end_k.6 ], [ %198, %for_begin_n.inner.preheader.7 ]
#   %indvars.iv10.7 = phi i64 [ 0, %for_end_k.6 ], [ %indvars.iv.next11.7, %for_begin_n.inner.preheader.7 ]
#   %lsr.iv279281 = bitcast float* %lsr.iv279 to <8 x float>*
#   %scevgep285 = getelementptr float, float* %lsr.iv227, i64 %indvars.iv10.7
#   %197 = load float, float* %scevgep285, align 4, !tbaa !114
#   %broadcast.splatinsert20 = insertelement <8 x float> undef, float %197, i32 0
#   %broadcast.splat21 = shufflevector <8 x float> %broadcast.splatinsert20, <8 x float> undef, <8 x i32> zeroinitializer
#   %scevgep284 = getelementptr <8 x float>, <8 x float>* %lsr.iv279281, i64 -3
#   %wide.load = load <8 x float>, <8 x float>* %scevgep284, align 64, !tbaa !116
#   %198 = call <8 x float> @llvm.fmuladd.v8f32(<8 x float> %broadcast.splat21, <8 x float> %wide.load, <8 x float> %wide.load19210)
#   %scevgep283 = getelementptr <8 x float>, <8 x float>* %lsr.iv279281, i64 -2
#   %wide.load.1 = load <8 x float>, <8 x float>* %scevgep283, align 32, !tbaa !116
#   %199 = call <8 x float> @llvm.fmuladd.v8f32(<8 x float> %broadcast.splat21, <8 x float> %wide.load.1, <8 x float> %wide.load19.1213)
#   %scevgep282 = getelementptr <8 x float>, <8 x float>* %lsr.iv279281, i64 -1
#   %wide.load.2 = load <8 x float>, <8 x float>* %scevgep282, align 64, !tbaa !116
#   %200 = call <8 x float> @llvm.fmuladd.v8f32(<8 x float> %broadcast.splat21, <8 x float> %wide.load.2, <8 x float> %wide.load19.2216)
#   %wide.load.3 = load <8 x float>, <8 x float>* %lsr.iv279281, align 32, !tbaa !116
#   %201 = call <8 x float> @llvm.fmuladd.v8f32(<8 x float> %broadcast.splat21, <8 x float> %wide.load.3, <8 x float> %wide.load19.3219)
#   %indvars.iv.next11.7 = add nuw nsw i64 %indvars.iv10.7, 1
#   %scevgep280 = getelementptr float, float* %lsr.iv279, i64 256
#   %exitcond12.7 = icmp eq i64 %indvars.iv.next11.7, 256
#   br i1 %exitcond12.7, label %for_end_k.7, label %for_begin_n.inner.preheader.7, !prof !51
#
# for_end_k.7:                                      ; preds = %for_begin_n.inner.preheader.7
#   %sunkaddr341 = mul i64 %185, 4
#   %202 = bitcast float* %0 to i8*
#   %sunkaddr342 = getelementptr inbounds i8, i8* %202, i64 %sunkaddr341
#   %203 = bitcast i8* %sunkaddr342 to <8 x float>*
#   store <8 x float> %198, <8 x float>* %203, align 64, !tbaa !112
#   %sunkaddr343 = mul i64 %188, 4
#   %204 = bitcast float* %0 to i8*
#   %sunkaddr344 = getelementptr inbounds i8, i8* %204, i64 %sunkaddr343
#   %205 = bitcast i8* %sunkaddr344 to <8 x float>*
#   store <8 x float> %199, <8 x float>* %205, align 32, !tbaa !112
#   %sunkaddr345 = mul i64 %191, 4
#   %206 = bitcast float* %0 to i8*
#   %sunkaddr346 = getelementptr inbounds i8, i8* %206, i64 %sunkaddr345
#   %207 = bitcast i8* %sunkaddr346 to <8 x float>*
#   store <8 x float> %200, <8 x float>* %207, align 64, !tbaa !112
#   %sunkaddr347 = mul i64 %194, 4
#   %208 = bitcast float* %0 to i8*
#   %sunkaddr348 = getelementptr inbounds i8, i8* %208, i64 %sunkaddr347
#   %209 = bitcast i8* %sunkaddr348 to <8 x float>*
#   store <8 x float> %201, <8 x float>* %209, align 32, !tbaa !112
#   %indvar.next = add nuw nsw i64 %indvar, 1
#   %scevgep228 = getelementptr float, float* %lsr.iv227, i64 256
#   %exitcond18 = icmp eq i64 %indvar.next, 256
#   br i1 %exitcond18, label %for_end_m.outer, label %for_begin_n.outer.preheader, !prof !51
# }
#
# ; Function Attrs: nounwind readnone
# define weak dso_local i16 @__truncsfhf2(float %a0) local_unnamed_addr #3 section ".text.tvm.fp16.conv" {
# b0:
#   %v0 = bitcast float %a0 to i32
#   %v1 = and i32 %v0, 2147483647
#   %v2 = add nsw i32 %v1, -947912704
#   %v3 = add nsw i32 %v1, -1199570944
#   %v4 = icmp ult i32 %v2, %v3
#   br i1 %v4, label %b1, label %b5
#
# b1:                                               ; preds = %b0
#   %v5 = lshr i32 %v0, 13
#   %v6 = and i32 %v5, 65535
#   %v7 = add nuw nsw i32 %v6, -114688
#   %v8 = and i32 %v0, 8191
#   %v9 = icmp ugt i32 %v8, 4096
#   br i1 %v9, label %b2, label %b3
#
# b2:                                               ; preds = %b1
#   %v10 = add nuw nsw i32 %v6, -114687
#   br label %b13
#
# b3:                                               ; preds = %b1
#   %v11 = icmp eq i32 %v8, 4096
#   br i1 %v11, label %b4, label %b13
#
# b4:                                               ; preds = %b3
#   %v12 = and i32 %v7, 65535
#   %v13 = and i32 %v5, 1
#   %v14 = add nuw nsw i32 %v12, %v13
#   br label %b13
#
# b5:                                               ; preds = %b0
#   %v15 = icmp ugt i32 %v1, 2139095040
#   br i1 %v15, label %b6, label %b7
#
# b6:                                               ; preds = %b5
#   %v16 = lshr i32 %v0, 13
#   %v17 = and i32 %v16, 511
#   %v18 = or i32 %v17, 32256
#   br label %b13
#
# b7:                                               ; preds = %b5
#   %v19 = icmp ugt i32 %v1, 1199570943
#   br i1 %v19, label %b13, label %b8
#
# b8:                                               ; preds = %b7
#   %v20 = icmp ult i32 %v1, 754974720
#   br i1 %v20, label %b13, label %b9
#
# b9:                                               ; preds = %b8
#   %v21 = lshr i32 %v1, 23
#   %v22 = sub nsw i32 113, %v21
#   %v23 = and i32 %v0, 8388607
#   %v24 = or i32 %v23, 8388608
#   %v25 = add nsw i32 %v21, -81
#   %v26 = shl i32 %v24, %v25
#   %v27 = icmp ne i32 %v26, 0
#   %v28 = lshr i32 %v24, %v22
#   %v29 = zext i1 %v27 to i32
#   %v30 = lshr i32 %v28, 13
#   %v31 = and i32 %v28, 8191
#   %v32 = or i32 %v31, %v29
#   %v33 = icmp ugt i32 %v32, 4096
#   br i1 %v33, label %b10, label %b11
#
# b10:                                              ; preds = %b9
#   %v34 = add nuw nsw i32 %v30, 1
#   br label %b13
#
# b11:                                              ; preds = %b9
#   %v35 = icmp eq i32 %v32, 4096
#   br i1 %v35, label %b12, label %b13
#
# b12:                                              ; preds = %b11
#   %v36 = and i32 %v30, 1
#   %v37 = add nuw nsw i32 %v36, %v30
#   br label %b13
#
# b13:                                              ; preds = %b12, %b11, %b10, %b8, %b7, %b6, %b4, %b3, %b2
#   %v38 = phi i32 [ %v18, %b6 ], [ %v10, %b2 ], [ %v14, %b4 ], [ %v7, %b3 ], [ 31744, %b7 ], [ 0, %b8 ], [ %v34, %b10 ], [ %v37, %b12 ], [ %v30, %b11 ]
#   %v39 = lshr i32 %v0, 16
#   %v40 = and i32 %v39, 32768
#   %v41 = or i32 %v38, %v40
#   %vlast = trunc i32 %v41 to i16
#   ret i16 %vlast
# }
#
# ; Function Attrs: nounwind readnone
# define weak dso_local float @__extendhfsf2(i16 %a0) local_unnamed_addr #3 section ".text.tvm.fp16.conv" {
# b0:
#   %v1 = and i16 %a0, 32767
#   %v2 = zext i16 %v1 to i32
#   %v3 = add nsw i16 %v1, -1024
#   %v4 = icmp ult i16 %v3, 30720
#   br i1 %v4, label %b1, label %b2
#
# b1:                                               ; preds = %b0
#   %v5 = shl nuw nsw i32 %v2, 13
#   %v6 = add nuw nsw i32 %v5, 939524096
#   br label %b6
#
# b2:                                               ; preds = %b0
#   %0 = trunc i32 %v2 to i16
#   %v7 = icmp ugt i16 %0, 31743
#   br i1 %v7, label %b3, label %b4
#
# b3:                                               ; preds = %b2
#   %v8 = shl nuw nsw i32 %v2, 13
#   %v9 = or i32 %v8, 2139095040
#   br label %b6
#
# b4:                                               ; preds = %b2
#   %1 = trunc i32 %v2 to i16
#   %v10 = icmp eq i16 %1, 0
#   br i1 %v10, label %b6, label %b5
#
# b5:                                               ; preds = %b4
#   %2 = trunc i32 %v2 to i16
#   %v11 = icmp ult i16 %2, 256
#   %v12 = lshr i32 %v2, 8
#   %v13 = select i1 %v11, i32 %v2, i32 %v12
#   %v14 = select i1 %v11, i32 32, i32 24
#   %v15 = icmp ult i32 %v13, 16
#   %v16 = lshr i32 %v13, 4
#   %v17 = add nsw i32 %v14, -4
#   %v18 = select i1 %v15, i32 %v13, i32 %v16
#   %v19 = select i1 %v15, i32 %v14, i32 %v17
#   %v20 = icmp ult i32 %v18, 4
#   %v21 = lshr i32 %v18, 2
#   %v22 = add nsw i32 %v19, -2
#   %v23 = select i1 %v20, i32 %v18, i32 %v21
#   %v24 = select i1 %v20, i32 %v19, i32 %v22
#   %v25 = icmp ult i32 %v23, 2
#   %v26 = sub nsw i32 0, %v23
#   %v27 = select i1 %v25, i32 %v26, i32 -2
#   %v28 = add nsw i32 %v27, %v24
#   %v29 = add nsw i32 %v28, -8
#   %v30 = shl i32 %v2, %v29
#   %v31 = xor i32 %v30, 8388608
#   %v32 = shl i32 %v28, 23
#   %v33 = sub i32 1124073472, %v32
#   %v34 = or i32 %v31, %v33
#   br label %b6
#
# b6:                                               ; preds = %b5, %b4, %b3, %b1
#   %v35 = phi i32 [ %v6, %b1 ], [ %v9, %b3 ], [ %v34, %b5 ], [ 0, %b4 ]
#   %v36 = and i16 %a0, -32768
#   %v37 = zext i16 %v36 to i32
#   %v38 = shl nuw i32 %v37, 16
#   %v39 = or i32 %v35, %v38
#   %v40 = bitcast i32 %v39 to float
#   ret float %v40
# }
#
# ; Function Attrs: nounwind readnone speculatable willreturn
# declare void @llvm.dbg.value(metadata, metadata, metadata) #4
#
# ; Function Attrs: argmemonly nounwind willreturn
# declare void @llvm.memset.p0i8.i64(i8* nocapture writeonly, i8, i64, i1 immarg) #5
#
# ; Function Attrs: nounwind readnone speculatable willreturn
# declare <8 x float> @llvm.fmuladd.v8f32(<8 x float>, <8 x float>, <8 x float>) #4
#
# ; Function Attrs: nounwind
# declare void @llvm.stackprotector(i8*, i8**) #6
#
# attributes #0 = { "target-cpu"="core-avx2" }
# attributes #1 = { nounwind willreturn }
# attributes #2 = { nofree noinline nounwind "target-cpu"="core-avx2" }
# attributes #3 = { nounwind readnone "target-cpu"="core-avx2" "target-features" }
# attributes #4 = { nounwind readnone speculatable willreturn }
# attributes #5 = { argmemonly nounwind willreturn }
# attributes #6 = { nounwind }
#
# !llvm.dbg.cu = !{!0}
# !llvm.module.flags = !{!3, !4}
#
# !0 = distinct !DICompileUnit(language: DW_LANG_C, file: !1, producer: "TVM", isOptimized: false, runtimeVersion: 0, emissionKind: FullDebug, enums: !2)
# !1 = !DIFile(filename: "main.tir", directory: ".")
# !2 = !{}
# !3 = !{i32 2, !"tvm_target", !"llvm -mtriple=x86_64-unknown-linux-gnu -mcpu=core-avx2"}
# !4 = !{i32 4, !"Debug Info Version", i32 3}
# !5 = distinct !DISubprogram(name: "main.tir", scope: !1, file: !1, type: !6, spFlags: DISPFlagLocalToUnit | DISPFlagDefinition | DISPFlagOptimized, unit: !0, retainedNodes: !11)
# !6 = !DISubroutineType(types: !7)
# !7 = !{!8, !9, !10, !8, !9, !10, !9}
# !8 = !DIBasicType(name: "int32", size: 32, encoding: DW_ATE_signed)
# !9 = !DIDerivedType(tag: DW_TAG_pointer_type, baseType: null)
# !10 = !DIDerivedType(tag: DW_TAG_pointer_type, baseType: !8)
# !11 = !{!12, !13, !14, !15, !16, !17}
# !12 = !DILocalVariable(name: "arg1", arg: 1, scope: !5, file: !1, type: !9)
# !13 = !DILocalVariable(name: "arg2", arg: 2, scope: !5, file: !1, type: !10)
# !14 = !DILocalVariable(name: "arg3", arg: 3, scope: !5, file: !1, type: !8)
# !15 = !DILocalVariable(name: "arg4", arg: 4, scope: !5, file: !1, type: !9)
# !16 = !DILocalVariable(name: "arg5", arg: 5, scope: !5, file: !1, type: !10)
# !17 = !DILocalVariable(name: "arg6", arg: 6, scope: !5, file: !1, type: !9)
# !18 = !DILocation(line: 0, scope: !5)
# !19 = !{!"branch_weights", i32 1048576, i32 1}
# !20 = !{!21, !21, i64 0}
# !21 = !{!"ctx_ptr", !22, i64 0}
# !22 = !{!"tvm-tbaa"}
# !23 = !{!24, !24, i64 0}
# !24 = !{!"0x57bf07f3a220.w4.b0", !25, i64 0}
# !25 = !{!"0x57bf07f3a220.w8.b0", !26, i64 0}
# !26 = !{!"0x57bf07f3a220.w16.b0", !27, i64 0}
# !27 = !{!"0x57bf07f3a220.w32.b0", !28, i64 0}
# !28 = !{!"0x57bf07f3a220.w64.b0", !29, i64 0}
# !29 = !{!"0x57bf07f3a220.w128.b0", !30, i64 0}
# !30 = !{!"0x57bf07f3a220.w256.b0", !31, i64 0}
# !31 = !{!"0x57bf07f3a220.w512.b0", !32, i64 0}
# !32 = !{!"0x57bf07f3a220.w1024.b0", !33, i64 0}
# !33 = !{!"0x57bf07f3a220", !22, i64 0}
# !34 = !{!35, !35, i64 0}
# !35 = !{!"0x57bf07f3a220.w4.b4", !25, i64 0}
# !36 = !{!37, !37, i64 0}
# !37 = !{!"0x57bf07f3a220.w4.b8", !38, i64 0}
# !38 = !{!"0x57bf07f3a220.w8.b8", !26, i64 0}
# !39 = !{!40, !40, i64 0}
# !40 = !{!"0x57bf07f4cda0.w8.b0", !41, i64 0}
# !41 = !{!"0x57bf07f4cda0.w16.b0", !42, i64 0}
# !42 = !{!"0x57bf07f4cda0.w32.b0", !43, i64 0}
# !43 = !{!"0x57bf07f4cda0.w64.b0", !44, i64 0}
# !44 = !{!"0x57bf07f4cda0.w128.b0", !45, i64 0}
# !45 = !{!"0x57bf07f4cda0.w256.b0", !46, i64 0}
# !46 = !{!"0x57bf07f4cda0.w512.b0", !47, i64 0}
# !47 = !{!"0x57bf07f4cda0.w1024.b0", !48, i64 0}
# !48 = !{!"0x57bf07f4cda0", !22, i64 0}
# !49 = !{!50, !50, i64 0}
# !50 = !{!"0x57bf07f4cda0.w8.b8", !41, i64 0}
# !51 = !{!"branch_weights", i32 1, i32 1048576}
# !52 = !{!53, !53, i64 0}
# !53 = !{!"0x57bf07000de0.w8.b0", !54, i64 0}
# !54 = !{!"0x57bf07000de0.w16.b0", !55, i64 0}
# !55 = !{!"0x57bf07000de0.w32.b0", !56, i64 0}
# !56 = !{!"0x57bf07000de0.w64.b0", !57, i64 0}
# !57 = !{!"0x57bf07000de0.w128.b0", !58, i64 0}
# !58 = !{!"0x57bf07000de0.w256.b0", !59, i64 0}
# !59 = !{!"0x57bf07000de0.w512.b0", !60, i64 0}
# !60 = !{!"0x57bf07000de0.w1024.b0", !61, i64 0}
# !61 = !{!"0x57bf07000de0", !22, i64 0}
# !62 = !{!63, !63, i64 0}
# !63 = !{!"0x57bf07000de0.w8.b8", !54, i64 0}
# !64 = !{!65, !65, i64 0}
# !65 = !{!"0x57bf07f06860.w8.b0", !66, i64 0}
# !66 = !{!"0x57bf07f06860.w16.b0", !67, i64 0}
# !67 = !{!"0x57bf07f06860.w32.b0", !68, i64 0}
# !68 = !{!"0x57bf07f06860.w64.b0", !69, i64 0}
# !69 = !{!"0x57bf07f06860.w128.b0", !70, i64 0}
# !70 = !{!"0x57bf07f06860.w256.b0", !71, i64 0}
# !71 = !{!"0x57bf07f06860.w512.b0", !72, i64 0}
# !72 = !{!"0x57bf07f06860.w1024.b0", !73, i64 0}
# !73 = !{!"0x57bf07f06860", !22, i64 0}
# !74 = !{!75, !75, i64 0}
# !75 = !{!"0x57bf07f06860.w8.b8", !66, i64 0}
# !76 = !{!77, !77, i64 0}
# !77 = !{!"0x57bf07ea6150.w8.b0", !78, i64 0}
# !78 = !{!"0x57bf07ea6150.w16.b0", !79, i64 0}
# !79 = !{!"0x57bf07ea6150.w32.b0", !80, i64 0}
# !80 = !{!"0x57bf07ea6150.w64.b0", !81, i64 0}
# !81 = !{!"0x57bf07ea6150.w128.b0", !82, i64 0}
# !82 = !{!"0x57bf07ea6150.w256.b0", !83, i64 0}
# !83 = !{!"0x57bf07ea6150.w512.b0", !84, i64 0}
# !84 = !{!"0x57bf07ea6150.w1024.b0", !85, i64 0}
# !85 = !{!"0x57bf07ea6150", !22, i64 0}
# !86 = !{!87, !87, i64 0}
# !87 = !{!"0x57bf07ea6150.w8.b8", !78, i64 0}
# !88 = !{!89, !89, i64 0}
# !89 = !{!"0x57bf080130e0.w8.b0", !90, i64 0}
# !90 = !{!"0x57bf080130e0.w16.b0", !91, i64 0}
# !91 = !{!"0x57bf080130e0.w32.b0", !92, i64 0}
# !92 = !{!"0x57bf080130e0.w64.b0", !93, i64 0}
# !93 = !{!"0x57bf080130e0.w128.b0", !94, i64 0}
# !94 = !{!"0x57bf080130e0.w256.b0", !95, i64 0}
# !95 = !{!"0x57bf080130e0.w512.b0", !96, i64 0}
# !96 = !{!"0x57bf080130e0.w1024.b0", !97, i64 0}
# !97 = !{!"0x57bf080130e0", !22, i64 0}
# !98 = !{!99, !99, i64 0}
# !99 = !{!"0x57bf080130e0.w8.b8", !90, i64 0}
# !100 = !{!101, !101, i64 0}
# !101 = !{!"0x57bf07fcbef0.w8.b0", !102, i64 0}
# !102 = !{!"0x57bf07fcbef0.w16.b0", !103, i64 0}
# !103 = !{!"0x57bf07fcbef0.w32.b0", !104, i64 0}
# !104 = !{!"0x57bf07fcbef0.w64.b0", !105, i64 0}
# !105 = !{!"0x57bf07fcbef0.w128.b0", !106, i64 0}
# !106 = !{!"0x57bf07fcbef0.w256.b0", !107, i64 0}
# !107 = !{!"0x57bf07fcbef0.w512.b0", !108, i64 0}
# !108 = !{!"0x57bf07fcbef0.w1024.b0", !109, i64 0}
# !109 = !{!"0x57bf07fcbef0", !22, i64 0}
# !110 = !{!111, !111, i64 0}
# !111 = !{!"0x57bf07fcbef0.w8.b8", !102, i64 0}
# !112 = !{!113, !113, i64 0}
# !113 = !{!"0x57bf08067950", !22, i64 0}
# !114 = !{!115, !115, i64 0}
# !115 = !{!"0x57bf07f5be10", !22, i64 0}
# !116 = !{!117, !117, i64 0}
# !117 = !{!"0x57bf07fe3e90", !22, i64 0}
